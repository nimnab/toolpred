# %%
from __future__ import print_function
from bs4 import BeautifulSoup
import requests
from six.moves.urllib import parse

# %%
base = "https://mapi.yummly.com/mapi/v17/content/feed?tag=list.recipe.other.guided&start={}&limit=10"

r = requests.get(base.format(0))

# %%
a = r.json()

# %%
len(a['feed'])
# Out:
# 10

# %%
a['feed'][0].keys()
# Out:
# dict_keys(['display', 'type', 'promoted', 'proRecipe', 'tracking-id', 'seo', 'content'])

# %%
import json

# %%
with open ('/hri/localdisk/nnabizad/toolpreddata/yummly.json', 'r') as f:
    file = json.load(f)

# %%
file[0]['display']['displayName']
# Out:
# 'Broccoli and Brown Rice Bowls with Poached Eggs and Red Chilies'

# %%
file[0]['content'].keys()
# Out:
# dict_keys(['description', 'urbSubmitters', 'tags', 'preparationSteps', 'videos', 'moreContent', 'tagsAds', 'details', 'relatedContent', 'ingredientLines', 'unitSystem', 'reviews', 'relatedProducts', 'preparationStepCount', 'nutrition', 'yums', 'guidedVariations'])

# %%
file[0]['content']
# Out:
# {'description': {'mobileSectionName': 'Description',
#   'text': '"Putting an egg on it" makes most dishes more delicious, and this healthy one-bowl meal is no exception. With saltiness from soy sauce, sweetness from brown sugar, crunch from tender-crisp broccoli, and a hint of fire from chiles, the dish will satisfy every tastebud. The recipe is a Yummly original created by Ashley Strickland Freeman.',
#   'shortText': None},
#  'urbSubmitters': [],
#  'tags': {'cuisine': [{'display-name': 'Asian',
#     'tag-url': 'cuisine^cuisine-asian'}],
#   'nutrition': [{'display-name': 'Source of Omega-3s',
#     'tag-url': 'nutrition^nutrition-source-omega-3'},
#    {'display-name': 'Low Saturated Fat',
#     'tag-url': 'nutrition^nutrition-low-saturated-fat'},
#    {'display-name': 'High Vitamin C',
#     'tag-url': 'nutrition^nutrition-high-vitamin-c'},
#    {'display-name': 'High Protein',
#     'tag-url': 'nutrition^nutrition-high-protein'},
#    {'display-name': 'High Potassium',
#     'tag-url': 'nutrition^nutrition-high-potassium'},
#    {'display-name': 'High Iron', 'tag-url': 'nutrition^nutrition-high-iron'},
#    {'display-name': 'High Fiber', 'tag-url': 'nutrition^nutrition-high-fiber'},
#    {'display-name': 'High Carb', 'tag-url': 'nutrition^nutrition-high-carb'}],
#   'technique': [{'display-name': 'Boiling',
#     'tag-url': 'technique^technique-boiling'}]},
#  'preparationSteps': ['Bring water to a boil in a medium saucepan. Add rice and salt. Cover, reduce heat, and simmer until liquid is absorbed and rice is tender, about 40 minutes.',
#   'Mince garlic. Cut carrots in half crosswise, then slice lengthwise about 1/4 inch thick. Stack a few pieces at a time and cut lengthwise into matchsticks. Set vegetables aside.',
#   'Stir together soy sauce, water, brown sugar, and cornstarch in a small bowl. Set aside.',
#   'Cut larger broccoli florets into smaller pieces for even cooking. Heat vegetable oil and sesame oil in a large frying pan over medium-high heat. Add garlic, red pepper flakes, broccoli, and water and stir until broccoli is evenly coated. Cover and steam until broccoli is almost tender, 3-5 minutes.',
#   'Uncover and add carrots and reserved soy sauce mixture. Cook, stirring often, until sauce is thickened and carrots are tender-crisp, about 2 minutes. Set aside.',
#   'Fill a medium saucepan with at least 3 inches of water and bring to a simmer. Add vinegar. Crack 1 egg into a ramekin or small bowl and another into a second ramekin. Swirl the simmering water with a spoon to create a whirlpool and carefully add an egg to center of pan. Quickly add a second egg. Cook until done the way you like, 3-4 minutes for soft yolks. Remove eggs with a slotted spoon to a plate. Repeat with remaining eggs. (Pro Tip: Be sure the water is not boiling fiercely. A light simmer ensures that the eggs will poach gently and hold their shape.)',
#   'Slice chilies and green onions. Divide rice between serving bowls. Top each with broccoli mixture and a poached egg. Scatter chilies and green onions over bowls.'],
#  'videos': {'snapshotUrl': 'https://gv.yummlystatic.com/b9b4c416-e91a-4682-bbad-80b4ea4f0fc5/BXaJIE6STweGxtzVxUfR_Montage_Broccoli_and_Brown_Rice_Bowls_with_Poached_Eggs_and_Red_Chilies/thumbnail_high_00001.png',
#   'videoUrls': {'ios': 'https://gv.yummlystatic.com/b9b4c416-e91a-4682-bbad-80b4ea4f0fc5/BXaJIE6STweGxtzVxUfR_Montage_Broccoli_and_Brown_Rice_Bowls_with_Poached_Eggs_and_Red_Chilies/hls.m3u8',
#    'android': 'https://gv.yummlystatic.com/b9b4c416-e91a-4682-bbad-80b4ea4f0fc5/BXaJIE6STweGxtzVxUfR_Montage_Broccoli_and_Brown_Rice_Bowls_with_Poached_Eggs_and_Red_Chilies/dash.mpd'},
#   'videoDetails': {'ios': [{'videoTypeCode': 'step-montage',
#      'videoUrl': 'https://gv.yummlystatic.com/b9b4c416-e91a-4682-bbad-80b4ea4f0fc5/BXaJIE6STweGxtzVxUfR_Montage_Broccoli_and_Brown_Rice_Bowls_with_Poached_Eggs_and_Red_Chilies/hls.m3u8',
#      'hasAudio': False}],
#    'android': [{'videoTypeCode': 'step-montage',
#      'videoUrl': 'https://gv.yummlystatic.com/b9b4c416-e91a-4682-bbad-80b4ea4f0fc5/BXaJIE6STweGxtzVxUfR_Montage_Broccoli_and_Brown_Rice_Bowls_with_Poached_Eggs_and_Red_Chilies/dash.mpd',
#      'hasAudio': False}]},
#   'originalVideoUrl': 'https://s3.amazonaws.com/videos-yummly/BXaJIE6STweGxtzVxUfR_Montage_Broccoli_and_Brown_Rice_Bowls_with_Poached_Eggs_and_Red_Chilies.mp4'},
#  'moreContent': {'mobileSectionName': 'More From Yummly',
#   'queryParams': {'start': 0,
#    'authorId': 'Yummly',
#    'id': 'Broccoli-and-Brown-Rice-Bowls-with-Poached-Eggs-and-Red-Chilies-9088926',
#    'apiFeedType': 'moreFrom'},
#   'feed': []},
#  'tagsAds': {'adtag': [{'display-name': 'adtag asian',
#     'tag-url': 'adtag^adtag-asian'}]},
#  'details': {'directionsUrl': 'https://www.yummly.com/private/recipe/Broccoli-and-Brown-Rice-Bowls-with-Poached-Eggs-and-Red-Chilies-9088926?layout=prep-steps',
#   'totalTime': '1 hr',
#   'displayName': 'Yummly',
#   'images': [{'hostedLargeUrl': 'https://lh3.googleusercontent.com/qJ3xwiKGt8kzdEJVkbNIz7l6gTRISz33Hum_BgvxXdIdt3KR2HwQ3swO0kn_rpiuQgHaQrQ6Qht7NDiINRn7clg=s360',
#     'resizableImageUrl': 'https://lh3.googleusercontent.com/ONk1cKRKfAFZJCRI2Y133vnN7c-OrQAE-QMrVXnedLcGWqgaVObPyV_eRdpFfy028Y_rr61Yrk8MfO79D-zJIg',
#     'resizableImageHeight': 1080,
#     'resizableImageWidth': 1920}],
#   'name': 'Broccoli and Brown Rice Bowls with Poached Eggs and Red Chilies',
#   'keywords': ['poached egg',
#    'spicy brown rice',
#    'brown rice',
#    'rice bowl sauce',
#    'brown rice breakfast',
#    'fatayer bread',
#    'rice bowl',
#    'steamed vegetables with brown rice',
#    'brocolli with egg',
#    'rice bowls',
#    'broccoli',
#    'flavored brown rice',
#    'with broccoli with carrots',
#    'brown rice with soy sauce',
#    'eggs rice breakfast',
#    'breakfast rice bowl',
#    'low salt',
#    'carrot broccoli rice',
#    'cook sweet brown rice',
#    'poached egg on rice'],
#   'brand': None,
#   'id': 'Broccoli-and-Brown-Rice-Bowls-with-Poached-Eggs-and-Red-Chilies-9088926',
#   'attribution': {'html': "<a href='http://www.yummly.com/recipe/Broccoli-and-Brown-Rice-Bowls-with-Poached-Eggs-and-Red-Chilies-9088926'>Broccoli and Brown Rice Bowls with Poached Eggs and Red Chilies recipe</a> information powered by <img src='http://static.yummly.com/api-logo.png'/>",
#    'url': 'http://www.yummly.com/recipe/Broccoli-and-Brown-Rice-Bowls-with-Poached-Eggs-and-Red-Chilies-9088926',
#    'text': 'Broccoli and Brown Rice Bowls with Poached Eggs and Red Chilies recipes: information powered by Yummly',
#    'logo': 'http://static.yummly.com/api-logo.png'},
#   'recipeId': '0429ad39-3a2c-48be-8b45-649b924dc343',
#   'numberOfServings': 4,
#   'globalId': '0f4064bf-df91-474d-9fc1-d4655fd30939',
#   'totalTimeInSeconds': 3600,
#   'rating': 3.0},
#  'relatedContent': {'mobileSectionName': 'Related',
#   'queryParams': {'start': 0,
#    'apiFeedType': 'related',
#    'id': 'recipe:Broccoli-and-Brown-Rice-Bowls-with-Poached-Eggs-and-Red-Chilies-9088926'},
#   'feed': []},
#  'ingredientLines': [{'category': 'Drinks',
#    'amount': {'metric': {'unit': {'id': '1248a02e-6e69-102c-9a8a-0030485841f8',
#       'name': 'liter',
#       'abbreviation': 'liter',
#       'plural': 'liters',
#       'pluralAbbreviation': 'liters',
#       'kind': 'volume',
#       'decimal': True},
#      'quantity': 0.95},
#     'imperial': {'unit': {'id': '1246463a-6e69-102c-9a8a-0030485841f8',
#       'name': 'cup',
#       'abbreviation': 'cup',
#       'plural': 'cups',
#       'pluralAbbreviation': 'cups',
#       'kind': 'volume',
#       'decimal': False},
#      'quantity': 4.0}},
#    'unit': 'cup',
#    'ingredientId': '6ec4f660-96d8-45ac-a747-8bbf8e696872',
#    'categoryId': '2108da4e-13aa-4785-947c-fa6eb53b8407',
#    'relatedRecipeSearchTerm': [{'allowedIngredient': 'water'}],
#    'ingredient': 'water',
#    'id': 'eb769372-1b23-40d3-a056-c9ef2e6db61b',
#    'remainder': 'for rice',
#    'quantity': 4.0,
#    'wholeLine': '4 cup water (for rice)'},
#   {'category': 'Pasta & Grains',
#    'amount': {'metric': {'unit': {'id': '12485d26-6e69-102c-9a8a-0030485841f8',
#       'name': 'gram',
#       'abbreviation': 'g',
#       'plural': 'grams',
#       'pluralAbbreviation': 'grams',
#       'kind': 'mass',
#       'decimal': True},
#      'quantity': 278},
#     'imperial': {'unit': {'id': '1246463a-6e69-102c-9a8a-0030485841f8',
#       'name': 'cup',
#       'abbreviation': 'cup',
#       'plural': 'cups',
#       'pluralAbbreviation': 'cups',
#       'kind': 'volume',
#       'decimal': False},
#      'quantity': 1.5}},
#    'unit': 'cup',
#    'ingredientId': '1b6680f6-3372-4239-a373-21ab04533ba9',
#    'categoryId': 'e6d6ce43-2b19-417f-9e37-da6da6c57de4',
#    'relatedRecipeSearchTerm': [{'allowedIngredient': 'long grain brown rice'}],
#    'ingredient': 'long grain brown rice',
#    'id': '8b34d3f2-0fb0-4cdc-b3ca-959a9c6d58b3',
#    'remainder': '',
#    'quantity': 1.5,
#    'wholeLine': '1 1/2 cups long-grain brown rice'},
#   {'category': 'Baking & Cooking',
#    'amount': {'metric': {'unit': {'id': '124afc0c-6e69-102c-9a8a-0030485841f8',
#       'name': 'teaspoon',
#       'abbreviation': 'tsp.',
#       'plural': 'teaspoons',
#       'pluralAbbreviation': 'tsp.',
#       'kind': 'volume',
#       'decimal': False},
#      'quantity': 1.0},
#     'imperial': {'unit': {'id': '124afc0c-6e69-102c-9a8a-0030485841f8',
#       'name': 'teaspoon',
#       'abbreviation': 'tsp.',
#       'plural': 'teaspoons',
#       'pluralAbbreviation': 'tsp.',
#       'kind': 'volume',
#       'decimal': False},
#      'quantity': 1.0}},
#    'unit': 'teaspoon',
#    'ingredientId': 'e01cac82-90ba-4267-8201-4d4d16332fb4',
#    'categoryId': '48481730-6064-11e9-8647-d663bd873d93',
#    'relatedRecipeSearchTerm': [{'allowedIngredient': 'salt'}],
#    'ingredient': 'salt',
#    'id': '606423b5-80c2-4bec-9756-05f6445041f3',
#    'remainder': '',
#    'quantity': 1.0,
#    'wholeLine': '1 tsp. salt'},
#   {'category': 'Produce',
#    'amount': {'metric': {'unit': {'id': '203f101c-fe8f-102c-a985-0030485841f8',
#       'name': '',
#       'abbreviation': '',
#       'plural': '',
#       'pluralAbbreviation': '',
#       'kind': 'count',
#       'decimal': False},
#      'quantity': 4.0},
#     'imperial': {'unit': {'id': '203f101c-fe8f-102c-a985-0030485841f8',
#       'name': '',
#       'abbreviation': '',
#       'plural': '',
#       'pluralAbbreviation': '',
#       'kind': 'count',
#       'decimal': False},
#      'quantity': 4.0}},
#    'unit': '',
#    'ingredientId': '797b9b50-252b-4440-8fa9-4a71519c8d6a',
#    'categoryId': '48480f6a-6064-11e9-8647-d663bd873d93',
#    'relatedRecipeSearchTerm': [{'allowedIngredient': 'garlic cloves'}],
#    'ingredient': 'garlic cloves',
#    'id': 'db9a62e0-fd52-4555-bd72-d3d4dcb1d854',
#    'remainder': '',
#    'quantity': 4.0,
#    'wholeLine': '4 garlic cloves'},
#   {'category': 'Produce',
#    'amount': {'metric': {'unit': {'id': '203f101c-fe8f-102c-a985-0030485841f8',
#       'name': '',
#       'abbreviation': '',
#       'plural': '',
#       'pluralAbbreviation': '',
#       'kind': 'count',
#       'decimal': False},
#      'quantity': 3.0},
#     'imperial': {'unit': {'id': '203f101c-fe8f-102c-a985-0030485841f8',
#       'name': '',
#       'abbreviation': '',
#       'plural': '',
#       'pluralAbbreviation': '',
#       'kind': 'count',
#       'decimal': False},
#      'quantity': 3.0}},
#    'unit': '',
#    'ingredientId': 'd0961595-18d6-4a13-87be-3e2b9e2c7845',
#    'categoryId': '48480f6a-6064-11e9-8647-d663bd873d93',
#    'relatedRecipeSearchTerm': [{'allowedIngredient': 'medium carrots'}],
#    'ingredient': 'medium carrots',
#    'id': 'b8c9a39c-d531-4e80-be7f-a224a6507ed2',
#    'remainder': '',
#    'quantity': 3.0,
#    'wholeLine': '3 medium carrots'},
#   {'category': 'Condiments',
#    'amount': {'metric': {'unit': {'id': '1248a146-6e69-102c-9a8a-0030485841f8',
#       'name': 'milliliter',
#       'abbreviation': 'ml',
#       'plural': 'milliliters',
#       'pluralAbbreviation': 'ml',
#       'kind': 'volume',
#       'decimal': True},
#      'quantity': 118},
#     'imperial': {'unit': {'id': '1246463a-6e69-102c-9a8a-0030485841f8',
#       'name': 'cup',
#       'abbreviation': 'cup',
#       'plural': 'cups',
#       'pluralAbbreviation': 'cups',
#       'kind': 'volume',
#       'decimal': False},
#      'quantity': 0.5}},
#    'unit': 'cup',
#    'ingredientId': '966d17c6-c75e-4dd1-a0e1-b2da31506815',
#    'categoryId': '8b69687e-72ad-484a-8e94-413f63ef9384',
#    'relatedRecipeSearchTerm': [{'allowedIngredient': 'reduced-sodium soy sauce'}],
#    'ingredient': 'reduced sodium soy sauce',
#    'id': '6e741b69-bcea-4b08-884b-23bd9c90951e',
#    'remainder': '',
#    'quantity': 0.5,
#    'wholeLine': '1/2 cup reduced-sodium soy sauce'},
#   {'category': 'Drinks',
#    'amount': {'metric': {'unit': {'id': '1248a146-6e69-102c-9a8a-0030485841f8',
#       'name': 'milliliter',
#       'abbreviation': 'ml',
#       'plural': 'milliliters',
#       'pluralAbbreviation': 'ml',
#       'kind': 'volume',
#       'decimal': True},
#      'quantity': 59},
#     'imperial': {'unit': {'id': '1246463a-6e69-102c-9a8a-0030485841f8',
#       'name': 'cup',
#       'abbreviation': 'cup',
#       'plural': 'cups',
#       'pluralAbbreviation': 'cups',
#       'kind': 'volume',
#       'decimal': False},
#      'quantity': 0.25}},
#    'unit': 'cup',
#    'ingredientId': '6ec4f660-96d8-45ac-a747-8bbf8e696872',
#    'categoryId': '2108da4e-13aa-4785-947c-fa6eb53b8407',
#    'relatedRecipeSearchTerm': [{'allowedIngredient': 'water'}],
#    'ingredient': 'water',
#    'id': 'bdb2cc3c-9293-4c5b-b92d-facefd1a4c32',
#    'remainder': 'for sauce',
#    'quantity': 0.25,
#    'wholeLine': '1/4 cup water (for sauce)'},
#   {'category': 'Baking & Cooking',
#    'amount': {'metric': {'unit': {'id': '124a0414-6e69-102c-9a8a-0030485841f8',
#       'name': 'tablespoon',
#       'abbreviation': 'Tbsp.',
#       'plural': 'tablespoons',
#       'pluralAbbreviation': 'Tbsp.',
#       'kind': 'volume',
#       'decimal': False},
#      'quantity': 2.0},
#     'imperial': {'unit': {'id': '124a0414-6e69-102c-9a8a-0030485841f8',
#       'name': 'tablespoon',
#       'abbreviation': 'Tbsp.',
#       'plural': 'tablespoons',
#       'pluralAbbreviation': 'Tbsp.',
#       'kind': 'volume',
#       'decimal': False},
#      'quantity': 2.0}},
#    'unit': 'tablespoon',
#    'ingredientId': '43baae1c-0444-41ba-9383-c4ef0839d345',
#    'categoryId': '48481730-6064-11e9-8647-d663bd873d93',
#    'relatedRecipeSearchTerm': [{'allowedIngredient': 'light brown sugar'}],
#    'ingredient': 'light brown sugar',
#    'id': '7d40ee5a-d59b-4394-9267-2e1211a68dca',
#    'remainder': 'packed',
#    'quantity': 2.0,
#    'wholeLine': '2 Tbsp. light brown sugar (packed)'},
#   {'category': 'Baking & Cooking',
#    'amount': {'metric': {'unit': {'id': '124a0414-6e69-102c-9a8a-0030485841f8',
#       'name': 'tablespoon',
#       'abbreviation': 'Tbsp.',
#       'plural': 'tablespoons',
#       'pluralAbbreviation': 'Tbsp.',
#       'kind': 'volume',
#       'decimal': False},
#      'quantity': 2.0},
#     'imperial': {'unit': {'id': '124a0414-6e69-102c-9a8a-0030485841f8',
#       'name': 'tablespoon',
#       'abbreviation': 'Tbsp.',
#       'plural': 'tablespoons',
#       'pluralAbbreviation': 'Tbsp.',
#       'kind': 'volume',
#       'decimal': False},
#      'quantity': 2.0}},
#    'unit': 'tablespoon',
#    'ingredientId': '694549c9-45c4-469a-a810-052312f2d7a7',
#    'categoryId': '48481730-6064-11e9-8647-d663bd873d93',
#    'relatedRecipeSearchTerm': [{'allowedIngredient': 'cornstarch'}],
#    'ingredient': 'cornstarch',
#    'id': 'c3e7beb8-8ac9-4033-ab03-b7d9452b6896',
#    'remainder': '',
#    'quantity': 2.0,
#    'wholeLine': '2 Tbsp. cornstarch'},
#   {'category': 'Produce',
#    'amount': {'metric': {'unit': {'id': '12487144-6e69-102c-9a8a-0030485841f8',
#       'name': 'kilogram',
#       'abbreviation': 'kg',
#       'plural': 'kilograms',
#       'pluralAbbreviation': 'kilograms',
#       'kind': 'mass',
#       'decimal': True},
#      'quantity': 0.68},
#     'imperial': {'unit': {'id': '12493192-6e69-102c-9a8a-0030485841f8',
#       'name': 'pound',
#       'abbreviation': 'lb.',
#       'plural': 'pounds',
#       'pluralAbbreviation': 'lb.',
#       'kind': 'mass',
#       'decimal': False},
#      'quantity': 1.5}},
#    'unit': 'pound',
#    'ingredientId': '92c6bcb3-6fea-487b-8cd1-1e4f34ef57ea',
#    'categoryId': '48480f6a-6064-11e9-8647-d663bd873d93',
#    'relatedRecipeSearchTerm': [{'allowedIngredient': 'broccoli florets'}],
#    'ingredient': 'broccoli florets',
#    'id': '458ac3c9-e42b-4e20-bf21-67e53c01fb13',
#    'remainder': '',
#    'quantity': 1.5,
#    'wholeLine': '1 1/2 lb. broccoli florets'},
#   {'category': 'Baking & Cooking',
#    'amount': {'metric': {'unit': {'id': '124a0414-6e69-102c-9a8a-0030485841f8',
#       'name': 'tablespoon',
#       'abbreviation': 'Tbsp.',
#       'plural': 'tablespoons',
#       'pluralAbbreviation': 'Tbsp.',
#       'kind': 'volume',
#       'decimal': False},
#      'quantity': 2.0},
#     'imperial': {'unit': {'id': '124a0414-6e69-102c-9a8a-0030485841f8',
#       'name': 'tablespoon',
#       'abbreviation': 'Tbsp.',
#       'plural': 'tablespoons',
#       'pluralAbbreviation': 'Tbsp.',
#       'kind': 'volume',
#       'decimal': False},
#      'quantity': 2.0}},
#    'unit': 'tablespoon',
#    'ingredientId': 'ab771b6c-d832-44c3-84c9-c10250e6946c',
#    'categoryId': '48481730-6064-11e9-8647-d663bd873d93',
#    'relatedRecipeSearchTerm': [{'allowedIngredient': 'vegetable oil'}],
#    'ingredient': 'vegetable oil',
#    'id': '07732bca-5010-46c2-a4bb-7bf409ec72c4',
#    'remainder': '',
#    'quantity': 2.0,
#    'wholeLine': '2 Tbsp. vegetable oil'},
#   {'category': 'Baking & Cooking',
#    'amount': {'metric': {'unit': {'id': '124afc0c-6e69-102c-9a8a-0030485841f8',
#       'name': 'teaspoon',
#       'abbreviation': 'tsp.',
#       'plural': 'teaspoons',
#       'pluralAbbreviation': 'tsp.',
#       'kind': 'volume',
#       'decimal': False},
#      'quantity': 4.0},
#     'imperial': {'unit': {'id': '124afc0c-6e69-102c-9a8a-0030485841f8',
#       'name': 'teaspoon',
#       'abbreviation': 'tsp.',
#       'plural': 'teaspoons',
#       'pluralAbbreviation': 'tsp.',
#       'kind': 'volume',
#       'decimal': False},
#      'quantity': 4.0}},
#    'unit': 'teaspoon',
#    'ingredientId': 'e1319fc8-204c-4f18-9556-c73e658fcaa0',
#    'categoryId': '48481730-6064-11e9-8647-d663bd873d93',
#    'relatedRecipeSearchTerm': [{'allowedIngredient': 'toasted sesame oil'}],
#    'ingredient': 'toasted sesame oil',
#    'id': '1581308b-7b12-46bd-a0c2-dd9c3ebc09be',
#    'remainder': '',
#    'quantity': 4.0,
#    'wholeLine': '4 tsp. toasted sesame oil'},
#   {'category': 'Baking & Cooking',
#    'amount': {'metric': {'unit': {'id': '124afc0c-6e69-102c-9a8a-0030485841f8',
#       'name': 'teaspoon',
#       'abbreviation': 'tsp.',
#       'plural': 'teaspoons',
#       'pluralAbbreviation': 'tsp.',
#       'kind': 'volume',
#       'decimal': False},
#      'quantity': 0.5},
#     'imperial': {'unit': {'id': '124afc0c-6e69-102c-9a8a-0030485841f8',
#       'name': 'teaspoon',
#       'abbreviation': 'tsp.',
#       'plural': 'teaspoons',
#       'pluralAbbreviation': 'tsp.',
#       'kind': 'volume',
#       'decimal': False},
#      'quantity': 0.5}},
#    'unit': 'teaspoon',
#    'ingredientId': 'f7461aa9-32c6-4ef3-b869-a70460f064d9',
#    'categoryId': '48481730-6064-11e9-8647-d663bd873d93',
#    'relatedRecipeSearchTerm': [{'allowedIngredient': 'crushed red chilies'}],
#    'ingredient': 'crushed red pepper flakes',
#    'id': '54c5effa-eaaf-45cd-b9bb-69026352a8b2',
#    'remainder': '',
#    'quantity': 0.5,
#    'wholeLine': '1/2 tsp. crushed red pepper flakes'},
#   {'category': 'Drinks',
#    'amount': {'metric': {'unit': {'id': '1248a146-6e69-102c-9a8a-0030485841f8',
#       'name': 'milliliter',
#       'abbreviation': 'ml',
#       'plural': 'milliliters',
#       'pluralAbbreviation': 'ml',
#       'kind': 'volume',
#       'decimal': True},
#      'quantity': 59},
#     'imperial': {'unit': {'id': '1246463a-6e69-102c-9a8a-0030485841f8',
#       'name': 'cup',
#       'abbreviation': 'cup',
#       'plural': 'cups',
#       'pluralAbbreviation': 'cups',
#       'kind': 'volume',
#       'decimal': False},
#      'quantity': 0.25}},
#    'unit': 'cup',
#    'ingredientId': '6ec4f660-96d8-45ac-a747-8bbf8e696872',
#    'categoryId': '2108da4e-13aa-4785-947c-fa6eb53b8407',
#    'relatedRecipeSearchTerm': [{'allowedIngredient': 'water'}],
#    'ingredient': 'water',
#    'id': '00cccbf7-76b2-4814-984c-c07bc0dbf0cb',
#    'remainder': 'for vegetables',
#    'quantity': 0.25,
#    'wholeLine': '1/4 cup water (for vegetables)'},
#   {'category': 'Condiments',
#    'amount': {'metric': {'unit': {'id': '124afc0c-6e69-102c-9a8a-0030485841f8',
#       'name': 'teaspoon',
#       'abbreviation': 'tsp.',
#       'plural': 'teaspoons',
#       'pluralAbbreviation': 'tsp.',
#       'kind': 'volume',
#       'decimal': False},
#      'quantity': 1.0},
#     'imperial': {'unit': {'id': '124afc0c-6e69-102c-9a8a-0030485841f8',
#       'name': 'teaspoon',
#       'abbreviation': 'tsp.',
#       'plural': 'teaspoons',
#       'pluralAbbreviation': 'tsp.',
#       'kind': 'volume',
#       'decimal': False},
#      'quantity': 1.0}},
#    'unit': 'teaspoon',
#    'ingredientId': '8e1f977f-18ea-42e1-8e30-82ae09f48a94',
#    'categoryId': '8b69687e-72ad-484a-8e94-413f63ef9384',
#    'relatedRecipeSearchTerm': [{'allowedIngredient': 'white vinegar'}],
#    'ingredient': 'distilled white vinegar',
#    'id': '1814660b-7bb0-4e99-a934-20719a144274',
#    'remainder': '',
#    'quantity': 1.0,
#    'wholeLine': '1 tsp. distilled white vinegar'},
#   {'category': 'Dairy',
#    'amount': {'metric': {'unit': {'id': '203f101c-fe8f-102c-a985-0030485841f8',
#       'name': '',
#       'abbreviation': '',
#       'plural': '',
#       'pluralAbbreviation': '',
#       'kind': 'count',
#       'decimal': False},
#      'quantity': 4.0},
#     'imperial': {'unit': {'id': '203f101c-fe8f-102c-a985-0030485841f8',
#       'name': '',
#       'abbreviation': '',
#       'plural': '',
#       'pluralAbbreviation': '',
#       'kind': 'count',
#       'decimal': False},
#      'quantity': 4.0}},
#    'unit': '',
#    'ingredientId': '2ea89351-aab1-472d-82ec-f6a0c7ef61af',
#    'categoryId': 'd8efba0b-2538-4882-9298-7d8c4d175c5f',
#    'relatedRecipeSearchTerm': [{'allowedIngredient': 'large egg'}],
#    'ingredient': 'large eggs',
#    'id': '08b0be12-c443-42b5-bc1c-14b343d70212',
#    'remainder': '',
#    'quantity': 4.0,
#    'wholeLine': '4 large eggs'},
#   {'category': 'Produce',
#    'amount': {'metric': {'unit': {'id': '203f101c-fe8f-102c-a985-0030485841f8',
#       'name': '',
#       'abbreviation': '',
#       'plural': '',
#       'pluralAbbreviation': '',
#       'kind': 'count',
#       'decimal': False},
#      'quantity': 2.0},
#     'imperial': {'unit': {'id': '203f101c-fe8f-102c-a985-0030485841f8',
#       'name': '',
#       'abbreviation': '',
#       'plural': '',
#       'pluralAbbreviation': '',
#       'kind': 'count',
#       'decimal': False},
#      'quantity': 2.0}},
#    'unit': '',
#    'ingredientId': 'cd29fbdd-3479-43e5-bcc8-7c226a430c5e',
#    'categoryId': '48480f6a-6064-11e9-8647-d663bd873d93',
#    'relatedRecipeSearchTerm': [{'allowedIngredient': 'fresno chiles'}],
#    'ingredient': 'Fresno chilies',
#    'id': '1ff7d9f6-6ee3-46e8-ae1f-af2543425b55',
#    'remainder': 'or jalapeno chilies, preferably red',
#    'quantity': 2.0,
#    'wholeLine': '2 Fresno chilies (or jalapeno chilies, preferably red)'},
#   {'category': 'Produce',
#    'amount': {'metric': {'unit': {'id': '203f101c-fe8f-102c-a985-0030485841f8',
#       'name': '',
#       'abbreviation': '',
#       'plural': '',
#       'pluralAbbreviation': '',
#       'kind': 'count',
#       'decimal': False},
#      'quantity': 2.0},
#     'imperial': {'unit': {'id': '203f101c-fe8f-102c-a985-0030485841f8',
#       'name': '',
#       'abbreviation': '',
#       'plural': '',
#       'pluralAbbreviation': '',
#       'kind': 'count',
#       'decimal': False},
#      'quantity': 2.0}},
#    'unit': '',
#    'ingredientId': '0bfbf46d-240e-44e7-acb1-75db5af45d4b',
#    'categoryId': '48480f6a-6064-11e9-8647-d663bd873d93',
#    'relatedRecipeSearchTerm': [{'allowedIngredient': 'green onions'}],
#    'ingredient': 'green onions',
#    'id': '9c386464-30ac-4f9d-bf49-4ce5f0354a17',
#    'remainder': '',
#    'quantity': 2.0,
#    'wholeLine': '2 green onions'}],
#  'unitSystem': 'imperial',
#  'reviews': {'mobileSectionName': 'Reviews',
#   'totalReviewCount': 0,
#   'averageRating': None,
#   'reviews': [],
#   'thisUserReview': None,
#   'sortBy': 'create-time'},
#  'relatedProducts': {'mobileSectionName': 'Essential Tools',
#   'queryParams': {'start': 0,
#    'apiFeedType': 'related',
#    'id': 'recipe:Broccoli-and-Brown-Rice-Bowls-with-Poached-Eggs-and-Red-Chilies-9088926',
#    'relatedContentType': 'product'},
#   'feed': []},
#  'preparationStepCount': 7,
#  'nutrition': {'mobileSectionName': 'Nutrition',
#   'nutritionEstimates': [{'attribute': 'FAT_KCAL',
#     'value': 180.0,
#     'unit': {'name': 'calorie',
#      'abbreviation': 'kcal',
#      'plural': 'calories',
#      'decimal': True},
#     'display': {'value': 180.0, 'unit': None, 'percentDailyValue': None}},
#    {'attribute': 'K',
#     'value': 1.05,
#     'unit': {'name': 'gram',
#      'abbreviation': 'g',
#      'plural': 'grams',
#      'decimal': True},
#     'display': {'value': 1050.0, 'unit': 'mg', 'percentDailyValue': 30}},
#    {'attribute': 'FASAT',
#     'value': 3.76,
#     'unit': {'name': 'gram',
#      'abbreviation': 'g',
#      'plural': 'grams',
#      'decimal': True},
#     'display': {'value': 4.0, 'unit': 'g', 'percentDailyValue': 20}},
#    {'attribute': 'FE',
#     'value': 0.0,
#     'unit': {'name': 'gram',
#      'abbreviation': 'g',
#      'plural': 'grams',
#      'decimal': True},
#     'display': {'value': None, 'unit': None, 'percentDailyValue': 25.0}},
#    {'attribute': 'SUGAR',
#     'value': 14.39,
#     'unit': {'name': 'gram',
#      'abbreviation': 'g',
#      'plural': 'grams',
#      'decimal': True},
#     'display': {'value': 14.0, 'unit': 'g', 'percentDailyValue': None}},
#    {'attribute': 'FIBTG',
#     'value': 9.95,
#     'unit': {'name': 'gram',
#      'abbreviation': 'g',
#      'plural': 'grams',
#      'decimal': True},
#     'display': {'value': 10.0, 'unit': 'g', 'percentDailyValue': 40}},
#    {'attribute': 'PROCNT',
#     'value': 21.36,
#     'unit': {'name': 'gram',
#      'abbreviation': 'g',
#      'plural': 'grams',
#      'decimal': True},
#     'display': {'value': 21.0, 'unit': 'g', 'percentDailyValue': None}},
#    {'attribute': 'CHOCDF',
#     'value': 86.64,
#     'unit': {'name': 'gram',
#      'abbreviation': 'g',
#      'plural': 'grams',
#      'decimal': True},
#     'display': {'value': 87.0, 'unit': 'g', 'percentDailyValue': 29}},
#    {'attribute': 'CHOLE',
#     'value': 0.22,
#     'unit': {'name': 'gram',
#      'abbreviation': 'g',
#      'plural': 'grams',
#      'decimal': True},
#     'display': {'value': 215.0, 'unit': 'mg', 'percentDailyValue': 72}},
#    {'attribute': 'CA',
#     'value': 0.18,
#     'unit': {'name': 'gram',
#      'abbreviation': 'g',
#      'plural': 'grams',
#      'decimal': True},
#     'display': {'value': None, 'unit': None, 'percentDailyValue': 20.0}},
#    {'attribute': 'VITA_IU',
#     'value': 9113.13,
#     'unit': {'name': 'IU',
#      'abbreviation': 'IU',
#      'plural': 'IU',
#      'decimal': True},
#     'display': {'value': None, 'unit': None, 'percentDailyValue': 180.0}},
#    {'attribute': 'FATRN',
#     'value': 0.2,
#     'unit': {'name': 'gram',
#      'abbreviation': 'g',
#      'plural': 'grams',
#      'decimal': True},
#     'display': {'value': 0.0, 'unit': 'g', 'percentDailyValue': None}},
#    {'attribute': 'ENERC_KCAL',
#     'value': 597.57,
#     'unit': {'name': 'calorie',
#      'abbreviation': 'kcal',
#      'plural': 'calories',
#      'decimal': True},
#     'display': {'value': 600.0, 'unit': None, 'percentDailyValue': None}},
#    {'attribute': 'VITC',
#     'value': 0.16,
#     'unit': {'name': 'gram',
#      'abbreviation': 'g',
#      'plural': 'grams',
#      'decimal': True},
#     'display': {'value': None, 'unit': None, 'percentDailyValue': 260.0}},
#    {'attribute': 'FAT',
#     'value': 20.06,
#     'unit': {'name': 'gram',
#      'abbreviation': 'g',
#      'plural': 'grams',
#      'decimal': True},
#     'display': {'value': 20.0, 'unit': 'g', 'percentDailyValue': 31}},
#    {'attribute': 'NA',
#     'value': 1.92,
#     'unit': {'name': 'gram',
#      'abbreviation': 'g',
#      'plural': 'grams',
#      'decimal': True},
#     'display': {'value': 1920.0, 'unit': 'mg', 'percentDailyValue': 80}}]},
#  'yums': {'count': 372, 'this-user': 'none'},
#  'guidedVariations': [{'id': '2e157246-f9d9-4292-86ce-472ee23628b6',
#    'default': True,
#    'variationAttributes': [],
#    'connected': False,
#    'actions': [{'name': 'Stove',
#      'stepGroups': [{'steps': [{'displayText': 'Bring water to a boil in a medium saucepan. Add rice and salt. Cover, reduce heat, and simmer until liquid is absorbed and rice is tender, about 40 minutes.',
#          'equipment': [{'id': 'b9e36713-052a-4f48-b3f6-54115bf77d39',
#            'name': 'measuring cups'},
#           {'id': '9b6957a9-0733-482a-a868-04df2488a425',
#            'name': 'medium saucepan'}],
#          'ingredientLines': [{'ingredient': 'water',
#            'ingredientId': '6ec4f660-96d8-45ac-a747-8bbf8e696872',
#            'sortOrder': 0,
#            'amount': {'metric': {'unit': {'id': '1248a02e-6e69-102c-9a8a-0030485841f8',
#               'name': 'liter',
#               'abbreviation': 'liter',
#               'plural': 'liters',
#               'kind': 'volume',
#               'round?': False,
#               'decimal': True},
#              'quantity': 0.95},
#             'imperial': {'unit': {'id': '1246463a-6e69-102c-9a8a-0030485841f8',
#               'name': 'cup',
#               'abbreviation': 'cup',
#               'plural': 'cups',
#               'kind': 'volume',
#               'round?': False,
#               'decimal': False},
#              'quantity': 4}},
#            'category': 'Drinks',
#            'remainder': 'for rice'},
#           {'ingredient': 'long grain brown rice',
#            'ingredientId': '1b6680f6-3372-4239-a373-21ab04533ba9',
#            'sortOrder': 1,
#            'amount': {'metric': {'unit': {'id': '12485d26-6e69-102c-9a8a-0030485841f8',
#               'name': 'gram',
#               'abbreviation': 'g',
#               'plural': 'grams',
#               'kind': 'mass',
#               'round?': True,
#               'decimal': True},
#              'quantity': 278},
#             'imperial': {'unit': {'id': '1246463a-6e69-102c-9a8a-0030485841f8',
#               'name': 'cup',
#               'abbreviation': 'cup',
#               'plural': 'cups',
#               'kind': 'volume',
#               'round?': False,
#               'decimal': False},
#              'quantity': 1.5}},
#            'category': 'Rice & Other Grains'},
#           {'ingredient': 'salt',
#            'ingredientId': 'e01cac82-90ba-4267-8201-4d4d16332fb4',
#            'sortOrder': 2,
#            'amount': {'metric': {'unit': {'id': '124afc0c-6e69-102c-9a8a-0030485841f8',
#               'name': 'teaspoon',
#               'abbreviation': 'tsp',
#               'plural': 'teaspoons',
#               'kind': 'volume',
#               'round?': False,
#               'decimal': False},
#              'quantity': 1},
#             'imperial': {'unit': {'id': '124afc0c-6e69-102c-9a8a-0030485841f8',
#               'name': 'teaspoon',
#               'abbreviation': 'tsp',
#               'plural': 'teaspoons',
#               'kind': 'volume',
#               'round?': False,
#               'decimal': False},
#              'quantity': 1}},
#            'category': 'Seasonings'}],
#          'imageUrl': 'https://lh3.googleusercontent.com/G_rtiL4JVltcLYysYXX86kBHNHOUQxyYj-2o9cOJuwuBzPgIolYSwo4cLBZfQFRuniNEC-g6XaceSWN_3xwH2Q',
#          'video': {'snapshotUrl': 'https://gv.yummlystatic.com/7f68c868-012c-499c-a4f6-c0d06a2b3b79/BgAFaOi0Qnx1fjvZilow_Step_1_Broccoli_and_Brown_Rice_Bowls_with_Poached_Eggs_and_Red_Chilies/thumbnail_high_00001.png',
#           'videoUrls': {'ios': 'https://gv.yummlystatic.com/7f68c868-012c-499c-a4f6-c0d06a2b3b79/BgAFaOi0Qnx1fjvZilow_Step_1_Broccoli_and_Brown_Rice_Bowls_with_Poached_Eggs_and_Red_Chilies/hls.m3u8',
#            'android': 'https://gv.yummlystatic.com/7f68c868-012c-499c-a4f6-c0d06a2b3b79/BgAFaOi0Qnx1fjvZilow_Step_1_Broccoli_and_Brown_Rice_Bowls_with_Poached_Eggs_and_Red_Chilies/dash.mpd'},
#           'videoTypeCode': 'guided-step',
#           'hasAudio': False,
#           'originalVideoUrl': 'https://s3.amazonaws.com/videos-yummly/BgAFaOi0Qnx1fjvZilow_Step_1_Broccoli_and_Brown_Rice_Bowls_with_Poached_Eggs_and_Red_Chilies.mp4'}}]}]},
#     {'name': 'Prep',
#      'stepGroups': [{'steps': [{'displayText': 'Mince garlic. Cut carrots in half crosswise, then slice lengthwise about 1/4 inch thick. Stack a few pieces at a time and cut lengthwise into matchsticks. Set vegetables aside.',
#          'equipment': [{'id': '98674587-cad7-4bcc-926d-41845612c5ea',
#            'name': 'chef’s knife'},
#           {'id': '85acedac-8537-499b-880e-12a751c2b483',
#            'name': 'cutting board'}],
#          'ingredientLines': [{'ingredient': 'garlic cloves',
#            'ingredientId': '797b9b50-252b-4440-8fa9-4a71519c8d6a',
#            'sortOrder': 0,
#            'amount': {'metric': {'unit': {'id': '203f101c-fe8f-102c-a985-0030485841f8',
#               'name': '',
#               'abbreviation': '',
#               'plural': '',
#               'kind': 'count',
#               'round?': False,
#               'decimal': False},
#              'quantity': 4},
#             'imperial': {'unit': {'id': '203f101c-fe8f-102c-a985-0030485841f8',
#               'name': '',
#               'abbreviation': '',
#               'plural': '',
#               'kind': 'count',
#               'round?': False,
#               'decimal': False},
#              'quantity': 4}},
#            'category': 'Fresh Vegetables'},
#           {'ingredient': 'medium carrots',
#            'ingredientId': 'd0961595-18d6-4a13-87be-3e2b9e2c7845',
#            'sortOrder': 1,
#            'amount': {'metric': {'unit': {'id': '203f101c-fe8f-102c-a985-0030485841f8',
#               'name': '',
#               'abbreviation': '',
#               'plural': '',
#               'kind': 'count',
#               'round?': False,
#               'decimal': False},
#              'quantity': 3},
#             'imperial': {'unit': {'id': '203f101c-fe8f-102c-a985-0030485841f8',
#               'name': '',
#               'abbreviation': '',
#               'plural': '',
#               'kind': 'count',
#               'round?': False,
#               'decimal': False},
#              'quantity': 3}},
#            'category': 'Fresh Vegetables'}],
#          'imageUrl': 'https://lh3.googleusercontent.com/wH8DErMXlOODNFyAs4DseuuREowDzDTDt7ZMSjb7PrBdQYNC-ET9Pabg_mlwlZ4x9ZG_WyCk3Xu3Kp-eXoOYKg',
#          'video': {'snapshotUrl': 'https://gv.yummlystatic.com/2df967d6-5175-45ba-a55d-a5b6a15bac0d/h4pAQqIARACGfBYZ0wK3_Step_2_Broccoli_and_Brown_Rice_Bowls_with_Poached_Eggs_and_Red_Chilies/thumbnail_high_00001.png',
#           'videoUrls': {'ios': 'https://gv.yummlystatic.com/2df967d6-5175-45ba-a55d-a5b6a15bac0d/h4pAQqIARACGfBYZ0wK3_Step_2_Broccoli_and_Brown_Rice_Bowls_with_Poached_Eggs_and_Red_Chilies/hls.m3u8',
#            'android': 'https://gv.yummlystatic.com/2df967d6-5175-45ba-a55d-a5b6a15bac0d/h4pAQqIARACGfBYZ0wK3_Step_2_Broccoli_and_Brown_Rice_Bowls_with_Poached_Eggs_and_Red_Chilies/dash.mpd'},
#           'videoTypeCode': 'guided-step',
#           'hasAudio': False,
#           'originalVideoUrl': 'https://s3.amazonaws.com/videos-yummly/h4pAQqIARACGfBYZ0wK3_Step_2_Broccoli_and_Brown_Rice_Bowls_with_Poached_Eggs_and_Red_Chilies.mp4'}},
#         {'displayText': 'Stir together soy sauce, water, brown sugar, and cornstarch in a small bowl. Set aside.',
#          'equipment': [{'id': 'dc570302-01de-475d-b2fd-602e1d258b85',
#            'name': 'small bowl'},
#           {'id': '972f6774-b2ee-4b7a-bfe9-6a3985cf8af6',
#            'name': 'wooden spoon'},
#           {'id': 'b9e36713-052a-4f48-b3f6-54115bf77d39',
#            'name': 'measuring cups'},
#           {'id': 'c582953f-1754-4f62-9d03-56d243ef01f4',
#            'name': 'measuring spoons'}],
#          'ingredientLines': [{'ingredient': 'reduced-sodium soy sauce',
#            'ingredientId': '966d17c6-c75e-4dd1-a0e1-b2da31506815',
#            'sortOrder': 0,
#            'amount': {'metric': {'unit': {'id': '1248a146-6e69-102c-9a8a-0030485841f8',
#               'name': 'milliliter',
#               'abbreviation': 'ml',
#               'plural': 'milliliters',
#               'kind': 'volume',
#               'round?': True,
#               'decimal': True},
#              'quantity': 118},
#             'imperial': {'unit': {'id': '1246463a-6e69-102c-9a8a-0030485841f8',
#               'name': 'cup',
#               'abbreviation': 'cup',
#               'plural': 'cups',
#               'kind': 'volume',
#               'round?': False,
#               'decimal': False},
#              'quantity': 0.5}},
#            'category': 'Sauces & Marinades'},
#           {'ingredient': 'water',
#            'ingredientId': '6ec4f660-96d8-45ac-a747-8bbf8e696872',
#            'sortOrder': 1,
#            'amount': {'metric': {'unit': {'id': '1248a146-6e69-102c-9a8a-0030485841f8',
#               'name': 'milliliter',
#               'abbreviation': 'ml',
#               'plural': 'milliliters',
#               'kind': 'volume',
#               'round?': True,
#               'decimal': True},
#              'quantity': 59},
#             'imperial': {'unit': {'id': '1246463a-6e69-102c-9a8a-0030485841f8',
#               'name': 'cup',
#               'abbreviation': 'cup',
#               'plural': 'cups',
#               'kind': 'volume',
#               'round?': False,
#               'decimal': False},
#              'quantity': 0.25}},
#            'category': 'Drinks',
#            'remainder': 'for sauce'},
#           {'ingredient': 'light brown sugar',
#            'ingredientId': '43baae1c-0444-41ba-9383-c4ef0839d345',
#            'sortOrder': 2,
#            'amount': {'metric': {'unit': {'id': '124a0414-6e69-102c-9a8a-0030485841f8',
#               'name': 'tablespoon',
#               'abbreviation': 'tbsp',
#               'plural': 'tablespoons',
#               'kind': 'volume',
#               'round?': False,
#               'decimal': False},
#              'quantity': 2},
#             'imperial': {'unit': {'id': '124a0414-6e69-102c-9a8a-0030485841f8',
#               'name': 'tablespoon',
#               'abbreviation': 'tbsp',
#               'plural': 'tablespoons',
#               'kind': 'volume',
#               'round?': False,
#               'decimal': False},
#              'quantity': 2}},
#            'category': 'Sugar & Sweetener',
#            'remainder': 'packed'},
#           {'ingredient': 'cornstarch',
#            'ingredientId': '694549c9-45c4-469a-a810-052312f2d7a7',
#            'sortOrder': 3,
#            'amount': {'metric': {'unit': {'id': '124a0414-6e69-102c-9a8a-0030485841f8',
#               'name': 'tablespoon',
#               'abbreviation': 'tbsp',
#               'plural': 'tablespoons',
#               'kind': 'volume',
#               'round?': False,
#               'decimal': False},
#              'quantity': 2},
#             'imperial': {'unit': {'id': '124a0414-6e69-102c-9a8a-0030485841f8',
#               'name': 'tablespoon',
#               'abbreviation': 'tbsp',
#               'plural': 'tablespoons',
#               'kind': 'volume',
#               'round?': False,
#               'decimal': False},
#              'quantity': 2}},
#            'category': 'Other Baking Ingredients'}],
#          'imageUrl': 'https://lh3.googleusercontent.com/GFOHzvZK-Qj4Qy7_jKe8kRkrwG1xEjDf1lUR1-raa0F22DIQ9kYLAONfcfhjRSsliO4PhP7qt3GGPLbKXZ7XUhI',
#          'video': {'snapshotUrl': 'https://gv.yummlystatic.com/30d9fa3b-10d4-47b0-9ab2-dc5b829d2cd1/LkIHdcpkTriAWZBUYQt4_Step_3_Broccoli_and_Brown_Rice_Bowls_with_Poached_Eggs_and_Red_Chilies/thumbnail_high_00001.png',
#           'videoUrls': {'ios': 'https://gv.yummlystatic.com/30d9fa3b-10d4-47b0-9ab2-dc5b829d2cd1/LkIHdcpkTriAWZBUYQt4_Step_3_Broccoli_and_Brown_Rice_Bowls_with_Poached_Eggs_and_Red_Chilies/hls.m3u8',
#            'android': 'https://gv.yummlystatic.com/30d9fa3b-10d4-47b0-9ab2-dc5b829d2cd1/LkIHdcpkTriAWZBUYQt4_Step_3_Broccoli_and_Brown_Rice_Bowls_with_Poached_Eggs_and_Red_Chilies/dash.mpd'},
#           'videoTypeCode': 'guided-step',
#           'hasAudio': False,
#           'originalVideoUrl': 'https://s3.amazonaws.com/videos-yummly/LkIHdcpkTriAWZBUYQt4_Step_3_Broccoli_and_Brown_Rice_Bowls_with_Poached_Eggs_and_Red_Chilies.mp4'}}]}]},
#     {'name': 'Stove',
#      'stepGroups': [{'steps': [{'displayText': 'Cut larger broccoli florets into smaller pieces for even cooking. Heat vegetable oil and sesame oil in a large frying pan over medium-high heat. Add garlic, red pepper flakes, broccoli, and water and stir until broccoli is evenly coated. Cover and steam until broccoli is almost tender, 3-5 minutes.',
#          'equipment': [{'id': '85acedac-8537-499b-880e-12a751c2b483',
#            'name': 'cutting board'},
#           {'id': '98674587-cad7-4bcc-926d-41845612c5ea',
#            'name': 'chef’s knife'},
#           {'id': 'c582953f-1754-4f62-9d03-56d243ef01f4',
#            'name': 'measuring spoons'},
#           {'id': '4bceeb90-d76d-4c21-a1e1-cf12f6fb9d86', 'name': 'frying pan'},
#           {'id': 'be1405ef-f3c0-4a17-ae3b-4a8fa13e8dd8', 'name': 'lid'}],
#          'ingredientLines': [{'ingredient': 'broccoli florets',
#            'ingredientId': '92c6bcb3-6fea-487b-8cd1-1e4f34ef57ea',
#            'sortOrder': 0,
#            'amount': {'metric': {'unit': {'id': '12487144-6e69-102c-9a8a-0030485841f8',
#               'name': 'kilogram',
#               'abbreviation': 'kg',
#               'plural': 'kilograms',
#               'kind': 'mass',
#               'round?': False,
#               'decimal': True},
#              'quantity': 0.68},
#             'imperial': {'unit': {'id': '12493192-6e69-102c-9a8a-0030485841f8',
#               'name': 'pound',
#               'abbreviation': 'lb',
#               'plural': 'pounds',
#               'kind': 'mass',
#               'round?': False,
#               'decimal': False},
#              'quantity': 1.5}},
#            'category': 'Fresh Vegetables'},
#           {'ingredient': 'vegetable oil',
#            'ingredientId': 'ab771b6c-d832-44c3-84c9-c10250e6946c',
#            'sortOrder': 1,
#            'amount': {'metric': {'unit': {'id': '124a0414-6e69-102c-9a8a-0030485841f8',
#               'name': 'tablespoon',
#               'abbreviation': 'tbsp',
#               'plural': 'tablespoons',
#               'kind': 'volume',
#               'round?': False,
#               'decimal': False},
#              'quantity': 2},
#             'imperial': {'unit': {'id': '124a0414-6e69-102c-9a8a-0030485841f8',
#               'name': 'tablespoon',
#               'abbreviation': 'tbsp',
#               'plural': 'tablespoons',
#               'kind': 'volume',
#               'round?': False,
#               'decimal': False},
#              'quantity': 2}},
#            'category': 'Oil'},
#           {'ingredient': 'toasted sesame oil',
#            'ingredientId': 'e1319fc8-204c-4f18-9556-c73e658fcaa0',
#            'sortOrder': 2,
#            'amount': {'metric': {'unit': {'id': '124afc0c-6e69-102c-9a8a-0030485841f8',
#               'name': 'teaspoon',
#               'abbreviation': 'tsp',
#               'plural': 'teaspoons',
#               'kind': 'volume',
#               'round?': False,
#               'decimal': False},
#              'quantity': 4},
#             'imperial': {'unit': {'id': '124afc0c-6e69-102c-9a8a-0030485841f8',
#               'name': 'teaspoon',
#               'abbreviation': 'tsp',
#               'plural': 'teaspoons',
#               'kind': 'volume',
#               'round?': False,
#               'decimal': False},
#              'quantity': 4}},
#            'category': 'Oil'},
#           {'ingredient': 'crushed red chilies',
#            'ingredientId': 'f7461aa9-32c6-4ef3-b869-a70460f064d9',
#            'sortOrder': 3,
#            'amount': {'metric': {'unit': {'id': '124afc0c-6e69-102c-9a8a-0030485841f8',
#               'name': 'teaspoon',
#               'abbreviation': 'tsp',
#               'plural': 'teaspoons',
#               'kind': 'volume',
#               'round?': False,
#               'decimal': False},
#              'quantity': 0.5},
#             'imperial': {'unit': {'id': '124afc0c-6e69-102c-9a8a-0030485841f8',
#               'name': 'teaspoon',
#               'abbreviation': 'tsp',
#               'plural': 'teaspoons',
#               'kind': 'volume',
#               'round?': False,
#               'decimal': False},
#              'quantity': 0.5}},
#            'category': 'Seasonings'},
#           {'ingredient': 'water',
#            'ingredientId': '6ec4f660-96d8-45ac-a747-8bbf8e696872',
#            'sortOrder': 4,
#            'amount': {'metric': {'unit': {'id': '1248a146-6e69-102c-9a8a-0030485841f8',
#               'name': 'milliliter',
#               'abbreviation': 'ml',
#               'plural': 'milliliters',
#               'kind': 'volume',
#               'round?': True,
#               'decimal': True},
#              'quantity': 59},
#             'imperial': {'unit': {'id': '1246463a-6e69-102c-9a8a-0030485841f8',
#               'name': 'cup',
#               'abbreviation': 'cup',
#               'plural': 'cups',
#               'kind': 'volume',
#               'round?': False,
#               'decimal': False},
#              'quantity': 0.25}},
#            'category': 'Drinks',
#            'remainder': 'for vegetables'}],
#          'imageUrl': 'https://lh3.googleusercontent.com/vRpjO1pjCLm5D8d1U4mnSRQ3ccrsSNSEZQc4GP39krur8kyOKsQ3ekixsrb9bRMUduHMVD01O0v5HYUh4ABd0A',
#          'video': {'snapshotUrl': 'https://gv.yummlystatic.com/525f6c18-ff24-4b08-9a49-5683e1ae6448/ay8dcYwURv6XxC52stBe_Step_4_Broccoli_and_Brown_Rice_Bowls_with_Poached_Eggs_and_Red_Chilies/thumbnail_high_00001.png',
#           'videoUrls': {'ios': 'https://gv.yummlystatic.com/525f6c18-ff24-4b08-9a49-5683e1ae6448/ay8dcYwURv6XxC52stBe_Step_4_Broccoli_and_Brown_Rice_Bowls_with_Poached_Eggs_and_Red_Chilies/hls.m3u8',
#            'android': 'https://gv.yummlystatic.com/525f6c18-ff24-4b08-9a49-5683e1ae6448/ay8dcYwURv6XxC52stBe_Step_4_Broccoli_and_Brown_Rice_Bowls_with_Poached_Eggs_and_Red_Chilies/dash.mpd'},
#           'videoTypeCode': 'guided-step',
#           'hasAudio': False,
#           'originalVideoUrl': 'https://s3.amazonaws.com/videos-yummly/ay8dcYwURv6XxC52stBe_Step_4_Broccoli_and_Brown_Rice_Bowls_with_Poached_Eggs_and_Red_Chilies.mp4'}},
#         {'displayText': 'Uncover and add carrots and reserved soy sauce mixture. Cook, stirring often, until sauce is thickened and carrots are tender-crisp, about 2 minutes. Set aside.',
#          'equipment': [{'id': '4bceeb90-d76d-4c21-a1e1-cf12f6fb9d86',
#            'name': 'frying pan'},
#           {'id': '972f6774-b2ee-4b7a-bfe9-6a3985cf8af6',
#            'name': 'wooden spoon'}],
#          'ingredientLines': [],
#          'imageUrl': 'https://lh3.googleusercontent.com/k1XnT9KaDebsoxkVk5Jk7U51-L2nZTd3HDfWbgmpxXO6JuZMwWKZh9DG1481WTBwiDLQCAhWPLs_IkvGaOLAkLk',
#          'video': {'snapshotUrl': 'https://gv.yummlystatic.com/ac9db849-576b-40d9-b2fc-1a236f572cc3/bJJSbAiSPC9jhjjUT6GX_Step_5_Broccoli_and_Brown_Rice_Bowls_with_Poached_Eggs_and_Red_Chilies/thumbnail_high_00001.png',
#           'videoUrls': {'ios': 'https://gv.yummlystatic.com/ac9db849-576b-40d9-b2fc-1a236f572cc3/bJJSbAiSPC9jhjjUT6GX_Step_5_Broccoli_and_Brown_Rice_Bowls_with_Poached_Eggs_and_Red_Chilies/hls.m3u8',
#            'android': 'https://gv.yummlystatic.com/ac9db849-576b-40d9-b2fc-1a236f572cc3/bJJSbAiSPC9jhjjUT6GX_Step_5_Broccoli_and_Brown_Rice_Bowls_with_Poached_Eggs_and_Red_Chilies/dash.mpd'},
#           'videoTypeCode': 'guided-step',
#           'hasAudio': False,
#           'originalVideoUrl': 'https://s3.amazonaws.com/videos-yummly/bJJSbAiSPC9jhjjUT6GX_Step_5_Broccoli_and_Brown_Rice_Bowls_with_Poached_Eggs_and_Red_Chilies.mp4'}},
#         {'displayText': 'Fill a medium saucepan with at least 3 inches of water and bring to a simmer. Add vinegar. Crack 1 egg into a ramekin or small bowl and another into a second ramekin. Swirl the simmering water with a spoon to create a whirlpool and carefully add an egg to center of pan. Quickly add a second egg. Cook until done the way you like, 3-4 minutes for soft yolks. Remove eggs with a slotted spoon to a plate. Repeat with remaining eggs.',
#          'tip': 'Be sure the water is not boiling fiercely. A light simmer ensures that the eggs will poach gently and hold their shape.',
#          'equipment': [{'id': '9b6957a9-0733-482a-a868-04df2488a425',
#            'name': 'medium saucepan'},
#           {'id': 'c582953f-1754-4f62-9d03-56d243ef01f4',
#            'name': 'measuring spoons'},
#           {'id': '36432545-af29-43eb-bfd0-e4b2cb9b515d', 'name': 'ramekins'},
#           {'id': '0c1b3aec-1409-4c2c-9ec6-9101559f3daf',
#            'name': 'small bowls'},
#           {'id': '87144f8a-7a45-49d9-921a-14487d419b28',
#            'name': 'slotted spoon'},
#           {'id': 'f8116207-6448-42d9-bca1-5fcb232e0e9e', 'name': 'plate'}],
#          'ingredientLines': [{'ingredient': 'white vinegar',
#            'ingredientId': '8e1f977f-18ea-42e1-8e30-82ae09f48a94',
#            'sortOrder': 0,
#            'amount': {'metric': {'unit': {'id': '124afc0c-6e69-102c-9a8a-0030485841f8',
#               'name': 'teaspoon',
#               'abbreviation': 'tsp',
#               'plural': 'teaspoons',
#               'kind': 'volume',
#               'round?': False,
#               'decimal': False},
#              'quantity': 1},
#             'imperial': {'unit': {'id': '124afc0c-6e69-102c-9a8a-0030485841f8',
#               'name': 'teaspoon',
#               'abbreviation': 'tsp',
#               'plural': 'teaspoons',
#               'kind': 'volume',
#               'round?': False,
#               'decimal': False},
#              'quantity': 1}},
#            'category': 'Vinegar and Cooking Wines'},
#           {'ingredient': 'large egg',
#            'ingredientId': '2ea89351-aab1-472d-82ec-f6a0c7ef61af',
#            'sortOrder': 1,
#            'amount': {'metric': {'unit': {'id': '203f101c-fe8f-102c-a985-0030485841f8',
#               'name': '',
#               'abbreviation': '',
#               'plural': '',
#               'kind': 'count',
#               'round?': False,
#               'decimal': False},
#              'quantity': 4},
#             'imperial': {'unit': {'id': '203f101c-fe8f-102c-a985-0030485841f8',
#               'name': '',
#               'abbreviation': '',
#               'plural': '',
#               'kind': 'count',
#               'round?': False,
#               'decimal': False},
#              'quantity': 4}},
#            'category': 'Eggs'}],
#          'imageUrl': 'https://lh3.googleusercontent.com/e4DK-b-LJODGzJN5lXqDRY6WeqTpvTTIwIBjDq4FxmhomrJKAMqSTzlPAZxIF2CPkPVyMKKoHJzeble1UtOTcw',
#          'video': {'snapshotUrl': 'https://gv.yummlystatic.com/7b5bf4e2-b26f-4215-93f4-b55e4952d97c/kZeQUxDSQXeim1TMk95s_Step_6_Broccoli_and_Brown_Rice_Bowls_with_Poached_Eggs_and_Red_Chilies_v2/thumbnail_high_00001.png',
#           'videoUrls': {'ios': 'https://gv.yummlystatic.com/7b5bf4e2-b26f-4215-93f4-b55e4952d97c/kZeQUxDSQXeim1TMk95s_Step_6_Broccoli_and_Brown_Rice_Bowls_with_Poached_Eggs_and_Red_Chilies_v2/hls.m3u8',
#            'android': 'https://gv.yummlystatic.com/7b5bf4e2-b26f-4215-93f4-b55e4952d97c/kZeQUxDSQXeim1TMk95s_Step_6_Broccoli_and_Brown_Rice_Bowls_with_Poached_Eggs_and_Red_Chilies_v2/dash.mpd'},
#           'videoTypeCode': 'guided-step',
#           'hasAudio': False,
#           'originalVideoUrl': 'https://s3.amazonaws.com/videos-yummly/kZeQUxDSQXeim1TMk95s_Step_6_Broccoli_and_Brown_Rice_Bowls_with_Poached_Eggs_and_Red_Chilies_v2.mp4'}}]}]},
#     {'name': 'Serve',
#      'stepGroups': [{'steps': [{'displayText': 'Slice chilies and green onions. Divide rice between serving bowls. Top each with broccoli mixture and a poached egg. Scatter chilies and green onions over bowls.',
#          'equipment': [{'id': '85acedac-8537-499b-880e-12a751c2b483',
#            'name': 'cutting board'},
#           {'id': '98674587-cad7-4bcc-926d-41845612c5ea',
#            'name': 'chef’s knife'},
#           {'id': '32b4aa51-5871-4b38-b7ab-9ffb95fe2eec',
#            'name': 'serving bowls'},
#           {'id': '772b0f9a-3ad1-4c64-b1c3-cec98e334609', 'name': 'spoon'}],
#          'ingredientLines': [{'ingredient': 'fresno chiles',
#            'ingredientId': 'cd29fbdd-3479-43e5-bcc8-7c226a430c5e',
#            'sortOrder': 0,
#            'amount': {'metric': {'unit': {'id': '203f101c-fe8f-102c-a985-0030485841f8',
#               'name': '',
#               'abbreviation': '',
#               'plural': '',
#               'kind': 'count',
#               'round?': False,
#               'decimal': False},
#              'quantity': 2},
#             'imperial': {'unit': {'id': '203f101c-fe8f-102c-a985-0030485841f8',
#               'name': '',
#               'abbreviation': '',
#               'plural': '',
#               'kind': 'count',
#               'round?': False,
#               'decimal': False},
#              'quantity': 2}},
#            'category': 'Fresh Vegetables',
#            'remainder': 'preferably red, or jalapenos'},
#           {'ingredient': 'green onions',
#            'ingredientId': '0bfbf46d-240e-44e7-acb1-75db5af45d4b',
#            'sortOrder': 1,
#            'amount': {'metric': {'unit': {'id': '203f101c-fe8f-102c-a985-0030485841f8',
#               'name': '',
#               'abbreviation': '',
#               'plural': '',
#               'kind': 'count',
#               'round?': False,
#               'decimal': False},
#              'quantity': 2},
#             'imperial': {'unit': {'id': '203f101c-fe8f-102c-a985-0030485841f8',
#               'name': '',
#               'abbreviation': '',
#               'plural': '',
#               'kind': 'count',
#               'round?': False,
#               'decimal': False},
#              'quantity': 2}},
#            'category': 'Fresh Vegetables'}],
#          'imageUrl': 'https://lh3.googleusercontent.com/qq7q8DVlT3-QiVtUbI7lXo2_Swd-CrL3B3GoS4PL-t8dBKsQiHgsuANc5n8aGqKmQLrDnYEY0F-df8aL4fx-7A',
#          'video': {'snapshotUrl': 'https://gv.yummlystatic.com/1be4f754-909e-42af-939a-909a25c87507/I5aMb0eNQUG9Nh75Jtj5_Step_7_Broccoli_and_Brown_Rice_Bowls_with_Poached_Eggs_and_Red_Chilies/thumbnail_high_00001.png',
#           'videoUrls': {'ios': 'https://gv.yummlystatic.com/1be4f754-909e-42af-939a-909a25c87507/I5aMb0eNQUG9Nh75Jtj5_Step_7_Broccoli_and_Brown_Rice_Bowls_with_Poached_Eggs_and_Red_Chilies/hls.m3u8',
#            'android': 'https://gv.yummlystatic.com/1be4f754-909e-42af-939a-909a25c87507/I5aMb0eNQUG9Nh75Jtj5_Step_7_Broccoli_and_Brown_Rice_Bowls_with_Poached_Eggs_and_Red_Chilies/dash.mpd'},
#           'videoTypeCode': 'guided-step',
#           'hasAudio': False,
#           'originalVideoUrl': 'https://s3.amazonaws.com/videos-yummly/I5aMb0eNQUG9Nh75Jtj5_Step_7_Broccoli_and_Brown_Rice_Bowls_with_Poached_Eggs_and_Red_Chilies.mp4'}}]}]}]}]}

# %%
file[0]['content']['guidedVariations'][0].keys()
# Out:
# dict_keys(['id', 'default', 'variationAttributes', 'connected', 'actions'])

# %%
file[0]['content']['guidedVariations'][0]['actions'][1]['stepGroups'][0]['steps'][0]['equipment']
# Out:
# [{'id': '98674587-cad7-4bcc-926d-41845612c5ea', 'name': 'chef’s knife'},
#  {'id': '85acedac-8537-499b-880e-12a751c2b483', 'name': 'cutting board'}]

# %%
titles = []
recs = []
for rec in file:
    titles.append(rec['display']['displayName'])

# %%
def clean(txt):
    if 'x13' in txt:txt = '9x13-inch baking dish'

# %%
recs = []
titles = []
for rec in file:
    _tmp = []
    if 'guidedVariations' in rec['content'].keys():
        for step in rec['content']['guidedVariations'][0]['actions']:
            if 'equipment' in step['stepGroups'][0]['steps'][0]:
                eqs = [i['name'] for i in step['stepGroups'][0]['steps'][0]['equipment']]
                _tmp.append(eqs)
        if len(_tmp)>0:
            recs.append(_tmp)
            titles.append(rec['display']['displayName'])

# %%
len(recs)
# Out:
# 659

# %%
len(titles)
# Out:
# 659

# %%
import pickle as pk
def save_obj(obj, name):
    """
    Saving the pickle object
    """
    with open(name + '.pkl', 'wb') as file:
        pk.dump(obj, file, pk.HIGHEST_PROTOCOL)

# %%
save_obj(recs, 'recepies')

# %%
save_obj(titles, 'titles')

# %%
recs
# Out:
# [[['measuring cups', 'medium saucepan'],
#   ['chef’s knife', 'cutting board'],
#   ['cutting board', 'chef’s knife', 'measuring spoons', 'frying pan', 'lid'],
#   ['cutting board', 'chef’s knife', 'serving bowls', 'spoon']],
#  [['oven'],
#   ['9”x13” baking dish'],
#   ['skillet', 'stove', 'rubber spatula'],
#   ['large plate', 'paper towels', 'skillet'],
#   ['oven', 'oven mitts', 'toothpick'],
#   ['oven', 'oven mitts', 'toothpick'],
#   ['oven mitts', 'knife', 'spatula', 'serving spoon']],
#  [['kitchen scale', 'measuring cups', 'microwave-safe bowls'],
#   ['oven'],
#   ['cookie dough scoop',
#    'baking sheets',
#    'silicone baking mat',
#    'parchment paper'],
#   ['oven', 'oven mitts'],
#   ['oven', 'oven mitts'],
#   ['oven mitts', 'spatula', 'cooling rack']],
#  [['9x5-inch loaf pan'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'toothpicks'],
#   ['oven mitts', 'cooling rack'],
#   ['knife']],
#  [['knife', 'cutting board'],
#   ['oven mitts', 'tooth pick'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'bowl']],
#  [['sheet pans'],
#   ['oven mitts', 'sheet pans'],
#   ['oven mitts', 'sheet pans'],
#   ['chef’s knife',
#    'cutting board',
#    'measuring cups',
#    'sheet pans',
#    'spatula',
#    'serving bowl',
#    'serving spoon']],
#  [['9x13-inch baking dish', 'spoon'],
#   ['large skillet', 'measuring cups', 'measuring spoons', 'rubber spatula'],
#   ['mixing bowl', 'fork', 'rubber spatula'],
#   ['plate'],
#   ['oven mitts'],
#   ['oven mitts']],
#  [['measuring cups', 'measuring spoons', 'gallon-sized zip-top bags'],
#   ['baking sheet', 'aluminum foil'],
#   ['oven mitts'],
#   ['oven mitts', 'meat thermometer'],
#   ['plate']],
#  [['baking sheet', 'parchment paper'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['cooling rack']],
#  [['9x13-inch baking dish', 'parchment paper'],
#   ['oven mitts'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'platter', 'cooling rack'],
#   ['serrated knife', 'cake server']],
#  [['9-inch square pan'],
#   ['oven mitts'],
#   ['oven mitts', 'toothpick'],
#   ['sifter']],
#  [['oven'],
#   ['muffin pan'],
#   ['oven', 'oven mitts'],
#   ['oven', 'oven mitts'],
#   ['oven mitts', 'knife']],
#  [['9”x13” baking dish', 'spoon'],
#   ['extra-large skillet', 'measuring spoons', 'rubber spatula'],
#   ['measuring cups', 'mixing bowl', 'rubber spatula'],
#   ['plate'],
#   ['measuring cups', 'spoon', '9”x13” baking dish'],
#   ['oven mitts'],
#   ['oven mitts', 'meat thermometer'],
#   ['serving spoon']],
#  [['9x13-inch baking dish'],
#   ['9x13-inch baking dish'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['spoon']],
#  [['baking sheet', 'parchment paper'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['tongs', 'small bowls']],
#  [['plastic container', 'lid', 'plastic wrap'],
#   ['grill pan',
#    'frying pan',
#    'pastry brush',
#    'tongs',
#    'paper towels',
#    'platter',
#    'measuring spoons'],
#   ['chef’s knife', 'cutting board', 'platter']],
#  [['oven'],
#   ['muffin pan'],
#   ['skillet', 'stove', 'spatula', 'tongs'],
#   ['large mixing bowl', 'measuring cups', 'measuring spoons', 'whisk'],
#   ['oven', 'oven mitts', 'toothpick'],
#   ['oven', 'oven mitts', 'toothpick'],
#   ['muffin pan', 'oven mitts', 'knife', 'plates']],
#  [['muffin liners', 'muffin pan'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'toothpick'],
#   ['cooling rack', 'oven mitts'],
#   ['decorating bags', 'decorating tips', 'offset spatula']],
#  [['small mixing bowl', 'spoon', 'whisk'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['serving plate']],
#  [['cake pan'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'toothpick'],
#   ['butter knife', 'cooling rack'],
#   ['offset spatula', 'serrated knife', 'plate']],
#  [['sifter', 'small mixing bowl', 'measuring cups', 'measuring spoons'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['cooling racks', 'spatula']],
#  [['rice cooker', 'measuring cups', 'measuring spoons'],
#   ['large mixing bowl', 'measuring spoons', 'rubber spatula'],
#   ['oven mitts'],
#   ['oven mitts', 'fork'],
#   ['serving spoon']],
#  [['parchment paper', 'baking tray'], ['large mixing bowl']],
#  [['baking sheet', 'fork'],
#   ['oven mitts'],
#   ['large mixing bowl', 'whisk', 'measuring cups', 'measuring spoons'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['oven mitts', 'knife']],
#  [['oven'],
#   ['baking sheet', 'parchment paper'],
#   ['skillet', 'stove', 'measuring spoons', 'spatula'],
#   ['large mixing bowl', 'whisk'],
#   ['measuring spoons', 'spatula', 'skillet', 'stove'],
#   ['large spoon',
#    'kitchen scale',
#    'measuring cups',
#    'large mixing bowls',
#    'baking sheet',
#    'parchment paper'],
#   ['oven', 'oven mitts'],
#   ['oven', 'oven mitts'],
#   ['oven mitts', 'spoon']],
#  [['oven mitts', 'toothpick'], ['oven mitts', 'toothpick']],
#  [['mini muffin pan'],
#   ['blender', 'measuring cups', 'measuring spoons', 'kitchen scale'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['knife', 'mini muffin pan']],
#  [['baking sheets', 'parchment paper', 'silicone baking mat'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['oven mitts', 'cooling rack', 'spatula']],
#  [['oven'],
#   ['baking sheet', 'wire rack', 'aluminum foil'],
#   ['oven', 'oven mitts', 'meat thermometer'],
#   ['oven', 'oven mitts', 'meat thermometer'],
#   ['knife', 'cutting board']],
#  [['large shallow bowl', 'measuring cups', 'measuring spoons', 'fork'],
#   ['oven mitts', 'meat thermometer'],
#   ['oven mitts', 'meat thermometer'],
#   ['oven mitts', 'spatula', 'plates']],
#  [['chef’s knife', 'cutting board'],
#   ['skillet', 'large sauté pan', 'tongs', 'plate', 'measuring spoons'],
#   ['oven mitts', 'meat thermometer'],
#   ['oven mitts', 'meat thermometer'],
#   ['chef’s knife', 'cutting board', 'small bowl', 'spoon', 'serving spoon']],
#  [['Dutch oven', 'measuring cups', 'measuring spoons', 'wooden spoon'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['oven mitts', 'measuring spoons', 'wooden spoon']],
#  [['oven mitts'], ['oven mitts']],
#  [['sheet pans'],
#   ['oven mitts', 'sheet pans', 'knife'],
#   ['strainer', 'medium saucepan', 'measuring cups', 'measuring spoons'],
#   ['chef’s knife', 'cutting board'],
#   ['non stick frying pan', 'measuring spoons', 'wooden spoon'],
#   ['oven mitts', 'sheet pans', 'tongs', 'spoon'],
#   ['oven mitts', 'sheet pans'],
#   ['oven mitts', 'sheet pans'],
#   ['spatula', 'platter']],
#  [['9”x13” baking dish'], ['oven mitts'], ['oven mitts'], ['oven mitts']],
#  [['shallow baking dish', '9”x13” baking dish'],
#   ['sheet pan', 'oven mitts', 'large mixing bowl'],
#   ['frying pan',
#    'wooden spoon',
#    'peeler',
#    'chef’s knife',
#    'cutting board',
#    'large mixing bowl'],
#   ['medium mixing bowl',
#    'whisk',
#    'large mixing bowl',
#    'wooden spoon',
#    'shallow baking dish',
#    '9”x13” baking dish',
#    'aluminum foil'],
#   ['oven mitts'],
#   ['oven mitts', 'kitchen thermometer'],
#   ['9”x13” baking dish', 'shallow baking dish', 'serving spoon']],
#  [['baking sheet', 'parchment paper'],
#   ['oven mitts'],
#   ['knife', 'cutting board', 'oven mitts'],
#   ['measuring cups', 'plates', 'tongs']],
#  [['oven'],
#   ['square pan', 'parchment paper'],
#   ['oven', 'oven mitts'],
#   ['oven mitts', 'measuring cups', 'kitchen scale'],
#   ['oven', 'oven mitts', 'aluminum foil'],
#   ['oven', 'oven mitts'],
#   ['oven mitts', 'refrigerator'],
#   ['knife', 'cooling rack', 'cutting board', 'square pan', 'parchment paper']],
#  [['oven mitts'], ['oven mitts']],
#  [['plastic wrap', 'parchment paper', 'rolling pin', 'mallet'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['spatula']],
#  [['large plate', 'paper towels'],
#   ['stove', 'skillet', 'tongs'],
#   ['mixer',
#    'measuring cups',
#    'measuring spoons',
#    'kitchen scale',
#    'rubber spatula',
#    'large mixing bowl',
#    'stand mixer'],
#   ['oven'],
#   ['baking sheet', 'parchment paper', 'silicone baking mat'],
#   ['oven', 'oven mitts'],
#   ['oven', 'oven mitts'],
#   ['cooling rack', 'spatula']],
#  [['oven'],
#   ['parchment paper', 'baking sheet'],
#   ['oven', 'oven mitts'],
#   ['knife', 'cutting board'],
#   ['tongs', 'baking sheet', 'parchment paper', 'oven', 'oven mitts'],
#   ['oven', 'oven mitts'],
#   ['oven mitts', 'measuring spoons', 'tongs']],
#  [['oven'],
#   ['bundt pan'],
#   ['oven', 'oven mitts', 'toothpick'],
#   ['oven', 'oven mitts', 'toothpick'],
#   ['oven mitts', 'butter knife', 'serving plate']],
#  [['measuring spoons', '9”x13” baking dish', 'tongs'],
#   ['oven mitts', 'meat thermometer'],
#   ['oven mitts', 'meat thermometer'],
#   ['oven mitts', 'spatula']],
#  [['oven'],
#   ['baking sheet', 'parchment paper'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['spatula']],
#  [['oven'],
#   ['square pan'],
#   ['oven mitts'],
#   ['toothpick', 'oven mitts'],
#   ['refrigerator', 'sharp knife']],
#  [['large bowl', 'colander', 'oven mitts'],
#   ['wok', 'saute pan', 'tongs', 'measuring cups', 'rubber spatula'],
#   ['serving bowls', 'tongs']],
#  [['baking sheets', 'silicone baking mat', 'parchment paper'],
#   ['oven'],
#   ['oven', 'baking sheets', 'parchment paper', 'silicone baking mat'],
#   ['oven', 'oven mitts'],
#   ['oven mitts', 'spatula', 'cooling rack']],
#  [['oven'],
#   ['baking sheet', 'aluminum foil'],
#   ['fork', 'aluminum foil', 'oven mitts'],
#   ['knife', 'cutting board', 'large mixing bowl', 'spoon'],
#   ['oven', 'oven mitts', 'measuring spoons'],
#   ['oven', 'oven mitts']],
#  [['9x13-inch baking dish'],
#   ['measuring spoons', '9x13-inch baking dish'],
#   ['oven mitts'],
#   ['oven mitts', 'meat thermometer'],
#   ['oven mitts', 'spoons']],
#  [['oven'],
#   ['springform pan'],
#   ['microwave-safe bowls', 'measuring cups', 'kitchen scale', 'microwave'],
#   ['oven', 'oven mitts'],
#   ['oven', 'oven mitts'],
#   ['stand mixer',
#    'whisk attachment',
#    'measuring cups',
#    'kitchen scale',
#    'rubber spatula'],
#   ['oven', 'oven mitts'],
#   ['oven', 'oven mitts'],
#   ['refrigerator', 'oven']],
#  [['loaf pan'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'knife', 'cooling rack']],
#  [['measuring spoons', 'whisk', 'large zip-top bags', 'refrigerator'],
#   ['baking sheet', 'parchment paper'],
#   ['large skillet',
#    'measuring spoons',
#    'tongs',
#    'baking sheet',
#    'parchment paper'],
#   ['tongs', 'meat thermometer', 'oven mitts'],
#   ['oven mitts', 'meat thermometer'],
#   ['measuring spoons']],
#  [['oven'],
#   ['9-inch square pan'],
#   ['sauce pan', 'stove', 'measuring spoons', 'rubber spatula'],
#   ['9-inch square pan', 'measuring cups', 'kitchen scale', 'rubber spatula'],
#   ['oven', 'oven mitts'],
#   ['oven', 'oven mitts'],
#   ['oven mitts']],
#  [['sheet pan', 'parchment paper'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['tongs', 'plate']],
#  [['oven'],
#   ['roasting pan', 'roasting rack', 'aluminum foil', 'paper towels'],
#   ['measuring cups', 'measuring spoons', 'whisk', 'stove', 'saucepan'],
#   ['pastry brush',
#    'roasting pan',
#    'roasting rack',
#    'aluminum foil',
#    'saucepan'],
#   ['oven', 'oven mitts', 'spoon', 'pastry brush', 'meat thermometer'],
#   ['oven', 'oven mitts', 'meat thermometer'],
#   ['cutting board', 'knife']],
#  [['oven'],
#   ['bundt pan'],
#   ['oven', 'oven mitts', 'toothpick'],
#   ['oven', 'oven mitts', 'toothpick'],
#   ['oven mitts', 'butter knife', 'serving plate']],
#  [['baking sheet', 'parchment paper'],
#   ['oven mitts'],
#   ['meat thermometer', 'oven mitts'],
#   ['spatula']],
#  [['oven'],
#   ['baking sheet', 'wire rack', 'aluminum foil', 'fork'],
#   ['oven', 'oven mitts'],
#   ['oven', 'oven mitts'],
#   ['cooling rack', 'cutting board']],
#  [['muffin pan'], ['oven mitts'], ['oven mitts'], ['knife', 'muffin pan']],
#  [['sheet pan'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['plates', 'tongs', 'spatula']],
#  [['9x13-inch baking dish', 'parchment paper'],
#   ['oven mitts'],
#   ['oven mitts', 'toothpick'],
#   ['cooling rack', 'knife', 'serving plate', 'sheet pan', 'platter'],
#   ['serrated knife', 'cake server']],
#  [['baking sheet', 'parchment paper'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['plate', 'spatula']],
#  [['baking sheets', 'parchment paper'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['cast-iron skillet', 'rubber spatula', 'measuring spoons'],
#   ['large mixing bowl',
#    'measuring cups',
#    'measuring spoons',
#    'rubber spatula'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['oven mitts']],
#  [['colander', 'chef’s knife', 'cutting board', 'measuring spoons'],
#   ['frying pan',
#    'measuring spoons',
#    'wooden spoon',
#    'slow cooker',
#    'oven mitts',
#    'tongs',
#    'chef’s knife',
#    'cutting board'],
#   ['slow cooker',
#    'measuring cups',
#    'measuring spoons',
#    'can opener ',
#    'wooden spoon'],
#   ['chef’s knife',
#    'cutting board',
#    'measuring spoons',
#    'serving spoon',
#    'serving bowls']],
#  [['baking sheet', 'parchment paper'],
#   ['oven mitts', 'rubber spatula'],
#   ['oven mitts'],
#   ['serving spoon']],
#  [['baking sheet', 'aluminum foil'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['knife', 'cutting board']],
#  [['baking sheet', 'parchment paper'],
#   ['oven mitts', 'fork'],
#   ['oven mitts', 'fork'],
#   ['spoon', 'large mixing bowl', 'potato masher', 'fork', 'measuring spoons']],
#  [['9x5-inch loaf pan'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'cooling rack'],
#   ['oven mitts', 'knife', 'cutting board']],
#  [['9x13-inch baking dish'],
#   ['large pot', 'colander'],
#   ['9x13-inch baking dish', 'spoon', 'large pot', 'rubber spatula'],
#   ['oven mitts'],
#   ['oven mitts']],
#  [['serrated knife', 'cutting board'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['chef’s knife', 'cutting board'],
#   ['measuring spoons', 'non stick frying pan', 'wooden spoon'],
#   ['small bowl', 'spoon'],
#   ['serving plate']],
#  [['oven'],
#   ['baking sheet', 'aluminum foil'],
#   ['sauté pan',
#    'stove',
#    'measuring cups',
#    'measuring spoons',
#    'kitchen scale'],
#   ['mixing bowl', 'rubber spatula'],
#   ['oven', 'oven mitts'],
#   ['oven', 'oven mitts']],
#  [['baking pan', 'aluminum foil'], ['oven mitts'], ['oven mitts']],
#  [['can opener ',
#    'spatula',
#    'measuring cups',
#    '9x13-inch baking dish',
#    'rubber spatula'],
#   ['oven mitts', 'fork'],
#   ['oven mitts'],
#   ['serving spoon']],
#  [['oven'],
#   ['sheet pan', 'parchment paper'],
#   ['rubber spatula'],
#   ['oven mitts', 'fork'],
#   ['tongs']],
#  [['knife', 'cutting board'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'bowl']],
#  [['oven'],
#   ['springform pan'],
#   ['microwave', 'microwave-safe bowls', 'measuring cups', 'kitchen scale'],
#   ['mixing bowl', 'fork'],
#   ['oven', 'oven mitts'],
#   ['oven', 'oven mitts'],
#   ['stand mixer',
#    'whisk attachment',
#    'measuring cups',
#    'kitchen scale',
#    'rubber spatula'],
#   ['oven', 'oven mitts'],
#   ['oven', 'oven mitts'],
#   ['oven'],
#   ['knife']],
#  [['sheet pan', 'parchment paper'],
#   ['oven mitts', 'measuring spoons', 'fork'],
#   ['oven mitts', 'fork'],
#   ['oven mitts', 'serving spoon']],
#  [['oven'],
#   ['Dutch oven', 'measuring spoons', 'stove', 'rubber spatula'],
#   ['large plate', 'paper towels'],
#   ['Dutch oven', 'stove', 'tongs'],
#   ['Dutch oven'],
#   ['oven', 'oven mitts'],
#   ['oven', 'oven mitts'],
#   ['serving plate', 'slotted spoon', 'fork']],
#  [['sheet pan', 'parchment paper'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['baking sheet']],
#  [['shallow baking dish', 'measuring cups'],
#   ['oven mitts', 'sheet pan', 'wire rack', 'tongs', 'meat thermometer'],
#   ['oven mitts', 'meat thermometer'],
#   ['measuring cups', 'platter', 'ramekin', 'tongs']],
#  [['oven'],
#   ['springform pan'],
#   ['measuring cups', 'kitchen scale', 'microwave', 'microwave-safe bowls'],
#   ['mixing bowl', 'fork'],
#   ['oven', 'oven mitts'],
#   ['oven', 'oven mitts'],
#   ['stand mixer',
#    'measuring cups',
#    'kitchen scale',
#    'rubber spatula',
#    'whisk attachment'],
#   ['oven', 'oven mitts'],
#   ['oven', 'oven mitts'],
#   ['refrigerator'],
#   ['knife']],
#  [['oven'],
#   ['baking sheet', 'parchment paper'],
#   ['rubber spatula', 'oven', 'oven mitts'],
#   ['oven', 'oven mitts'],
#   ['spatula']],
#  [['cutting board'],
#   ['oven'],
#   ['small mixing bowl', 'measuring spoons', 'fork'],
#   ['oven', 'oven mitts'],
#   ['oven', 'oven mitts', 'meat thermometer'],
#   ['oven mitts', 'roasting pan', 'roasting rack', 'knife', 'cutting board']],
#  [['large mixing bowl',
#    'measuring cups',
#    'measuring spoons',
#    'stand mixer',
#    'paddle attachment',
#    'hand mixer'],
#   ['sheet pans', 'parchment paper'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['oven mitts', 'cooling rack'],
#   ['cutting board',
#    'chef’s knife',
#    'medium saucepan',
#    'small bowl',
#    'wooden spoon'],
#   ['baking sheets', 'measuring spoons']],
#  [['baking sheets', 'parchment paper', 'silicone baking mat'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['oven mitts', 'cooling rack', 'spatula']],
#  [['sheet pans'],
#   ['oven mitts', 'sheet pans'],
#   ['oven mitts', 'sheet pans'],
#   ['sheet pans', 'serving bowl', 'serving spoon']],
#  [['square pan', 'parchment paper'],
#   ['glass measuring cup', 'whisk', 'large mixing bowl'],
#   ['measuring spoons', 'whisk', 'glass measuring cup'],
#   ['oven mitts'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'cooling rack'],
#   ['glass measuring cup', 'microwave-safe bowls'],
#   ['strainer', 'sifter', 'whisk', 'measuring cups', 'measuring spoons'],
#   ['serrated knife', 'spatula']],
#  [['oven'],
#   ['9”x13” baking dish'],
#   ['oven', 'oven mitts', 'toothpick'],
#   ['oven', 'oven mitts', 'toothpick'],
#   ['knife', 'serving spoon', 'sifter', 'plates']],
#  [['chef’s knife', 'cutting board', 'sheet pan'],
#   ['oven mitts', 'spatula', 'wooden spoon'],
#   ['chef’s knife', 'cutting board'],
#   ['oven mitts', 'sheet pan', 'wooden spoon', 'spatula'],
#   ['oven mitts'],
#   ['spatula', 'plates', 'spoons']],
#  [['measuring cups', 'sheet pan'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['knife', 'cutting board'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['knife', 'cutting board']],
#  [['baking sheet', 'parchment paper'],
#   ['oven mitts', 'fork'],
#   ['oven mitts', 'fork'],
#   ['spatula']],
#  [['cake pan'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'toothpick'],
#   ['large mixing bowl',
#    'measuring cups',
#    'measuring spoons',
#    'hand mixer',
#    'rubber spatula',
#    'kitchen scale'],
#   ['offset spatula', 'parchment paper', 'cake stand', 'serving plate']],
#  [['oven'],
#   ['9”x13” baking dish'],
#   ['oven', 'oven mitts', 'toothpick'],
#   ['oven', 'oven mitts', 'toothpick'],
#   ['knife', 'serving spoon']],
#  [['oven'],
#   ['baking sheet', 'parchment paper'],
#   ['oven', 'oven mitts'],
#   ['oven', 'oven mitts'],
#   ['serving plate', 'tongs']],
#  [['waxed paper', 'parchment paper', 'sheet pan', '9”x13” baking dish'],
#   ['microwave-safe bowls', 'spoon'],
#   ['microwave-safe bowls',
#    'spoon',
#    'sheet pan',
#    'parchment paper',
#    'waxed paper'],
#   ['waxed paper']],
#  [['square baking dish'],
#   ['oven mitts'],
#   ['toothpick', 'oven mitts'],
#   ['sifter']],
#  [['9x13-inch baking dish'],
#   ['measuring spoons', 'rubber spatula', '9”x13” baking dish'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['measuring spoons']],
#  [['saucepan', 'rice cooker'],
#   ['frying pan',
#    'measuring spoons',
#    'wooden spoon',
#    'medium mixing bowl',
#    'rubber spatula'],
#   ['serving bowls', 'measuring cups', 'measuring spoons']],
#  [['oven'],
#   ['roasting pan', 'roasting rack', 'measuring cups'],
#   ['measuring spoons', 'small mixing bowl', 'whisk', 'measuring cups'],
#   ['spoon', 'baking sheet'],
#   ['oven mitts', 'meat thermometer'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['oven mitts', 'knife', 'cutting board', 'roasting pan', 'roasting rack']],
#  [['oven'],
#   ['baking sheet', 'parchment paper'],
#   ['oven', 'oven mitts', 'rubber spatula'],
#   ['oven', 'oven mitts', 'fork'],
#   ['spatula', 'spoon']],
#  [['oven'],
#   ['baking sheet', 'parchment paper'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['spatula']],
#  [['muffin liners', 'muffin pan'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'cooling rack'],
#   ['offset spatula', 'decorating bags', 'decorating tips', 'rubber spatula']],
#  [['large plate', 'fork'],
#   ['9x13-inch baking dish'],
#   ['oven mitts'],
#   ['oven mitts']],
#  [['9x13-inch baking dish'], ['oven mitts'], ['oven mitts']],
#  [['cast-iron skillet'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'knife']],
#  [['square baking dish'],
#   ['oven mitts'],
#   ['toothpick', 'oven mitts'],
#   ['sifter']],
#  [['9”x13” baking dish'],
#   ['large pot', 'colander'],
#   ['measuring cups',
#    'measuring spoons',
#    'large mixing bowl',
#    'rubber spatula'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['oven mitts']],
#  [['9”x13” baking dish'],
#   ['large pot', 'colander'],
#   ['measuring cups',
#    'measuring spoons',
#    'large mixing bowl',
#    'rubber spatula'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['oven mitts']],
#  [['muffin pan', 'cupcake liners'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'toothpick'],
#   ['offset spatula', 'piping bag', 'decorating tips']],
#  [['9x13-inch baking dish', 'spoon'],
#   ['plate'],
#   ['9x13-inch baking dish', 'spoon', 'measuring cups'],
#   ['oven mitts'],
#   ['oven mitts']],
#  [['baking sheet', 'parchment paper'],
#   ['measuring spoons', 'baking sheet', 'parchment paper', 'paper towels'],
#   ['oven mitts', 'meat thermometer', 'fork'],
#   ['oven mitts', 'meat thermometer', 'fork'],
#   ['serving plates', 'rubber spatula']],
#  [['9”x13” baking dish', 'parchment paper', 'scissors'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['cooling rack'],
#   ['offset spatula', 'knife']],
#  [['baking sheets', 'silicone baking mat'],
#   ['oven'],
#   ['oven',
#    'oven mitts',
#    'baking sheets',
#    'parchment paper',
#    'silicone baking mat'],
#   ['oven', 'oven mitts'],
#   ['oven mitts', 'spatula', 'cooling rack']],
#  [['cast-iron skillet', 'baking sheet', 'parchment paper'],
#   ['large mixing bowl',
#    'measuring cups',
#    'measuring spoons',
#    'rubber spatula'],
#   ['oven mitts'],
#   ['oven mitts']],
#  [['knife', 'platter', 'measuring spoons'],
#   ['Dutch oven', 'measuring spoons', 'tongs', 'spatula'],
#   ['tongs', 'spatula', 'platter'],
#   ['wooden spoon', 'measuring spoons', 'Dutch oven', 'measuring cups'],
#   ['oven mitts', 'fork'],
#   ['oven mitts', 'fork'],
#   ['oven mitts', 'spatula', 'cutting board', 'platter', 'aluminum foil'],
#   ['medium saucepan',
#    'measuring spoons',
#    'measuring cups',
#    'whisk',
#    'serving bowl'],
#   ['platter', 'knife', 'spatula', 'fork', 'serving spoon', 'spoon']],
#  [['oven'],
#   ['bundt pan'],
#   ['oven', 'oven mitts', 'toothpick'],
#   ['oven', 'oven mitts', 'toothpick'],
#   ['oven mitts', 'butter knife', 'serving plate']],
#  [['peeler', 'pairing knife', 'chef’s knife', 'cutting board'],
#   ['large pot', 'wooden spoon', 'measuring cups'],
#   ['immersion blender', 'potato masher'],
#   ['sheet pans'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['oven mitts', 'spatula', 'platter', 'serving bowls', 'serving spoons']],
#  [['oven'],
#   ['baking sheet', 'parchment paper'],
#   ['skillet', 'rubber spatula'],
#   ['large mixing bowl', 'whisk'],
#   ['skillet', 'stove', 'measuring spoons', 'spatula'],
#   ['large spoon',
#    'kitchen scale',
#    'measuring cups',
#    'baking sheet',
#    'parchment paper'],
#   ['oven', 'oven mitts'],
#   ['oven', 'oven mitts']],
#  [['oven'],
#   ['muffin liners', 'muffin pan'],
#   ['oven', 'oven mitts'],
#   ['oven', 'oven mitts', 'toothpick'],
#   ['oven mitts']],
#  [['oven'],
#   ['9”x13” baking dish'],
#   ['skillet',
#    'stove',
#    'measuring spoons',
#    'tongs',
#    '9”x13” baking dish',
#    'plate'],
#   ['oven', 'oven mitts', 'meat thermometer'],
#   ['oven', 'oven mitts', 'meat thermometer'],
#   ['oven', 'oven mitts', 'tongs', 'plate'],
#   ['skillet',
#    'stove',
#    'measuring spoons',
#    'whisk',
#    'rubber spatula',
#    'plate',
#    'tongs'],
#   ['spoon']],
#  [['oven'],
#   ['9-inch square pan'],
#   ['oven', 'oven mitts'],
#   ['oven', 'oven mitts'],
#   ['oven mitts', 'serving spoon']],
#  [['baking sheet', 'parchment paper'],
#   ['oven mitts', 'knife', 'cutting board'],
#   ['oven mitts'],
#   ['serving spoon']],
#  [['oven'],
#   ['baking sheet', 'aluminum foil', 'wire rack', 'knife'],
#   ['oven', 'oven mitts'],
#   ['oven', 'oven mitts'],
#   ['large plate', 'tongs']],
#  [['oven'],
#   ['roasting pan', 'roasting rack', 'aluminum foil'],
#   ['oven mitts'],
#   ['oven mitts', 'meat thermometer'],
#   ['knife', 'cutting board']],
#  [['oven'],
#   ['medium dish', 'measuring cup'],
#   ['oven mitts'],
#   ['oven mitts', 'meat thermometer'],
#   ['spoon', 'spatula']],
#  [['parchment paper', 'baking sheet'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['knife']],
#  [['cast-iron skillet', 'baking sheet', 'parchment paper'],
#   ['large mixing bowl',
#    'measuring cups',
#    'measuring spoons',
#    'rubber spatula'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['cast-iron skillet', 'baking sheet', 'serrated knife']],
#  [['oven'],
#   ['knife', 'cutting board'],
#   ['Dutch oven', 'stove'],
#   ['paper towels', 'large plate', 'measuring spoons'],
#   ['Dutch oven', 'tongs', 'stove', 'oven mitts'],
#   ['large plate', 'tongs', 'oven mitts', 'Dutch oven'],
#   ['Dutch oven', 'wooden spoon'],
#   ['Dutch oven', 'oven mitts'],
#   ['oven', 'oven mitts', 'fork'],
#   ['oven', 'oven mitts', 'fork'],
#   ['serving plate', 'slotted spoon', 'fork']],
#  [['sheet pan', 'parchment paper'],
#   ['oven mitts', 'tongs'],
#   ['oven mitts', 'meat thermometer'],
#   ['spatula', 'cutting board', 'knife', 'tongs', 'platter']],
#  [['oven'],
#   ['bundt pan'],
#   ['oven', 'oven mitts', 'toothpick'],
#   ['oven', 'oven mitts', 'toothpick'],
#   ['oven mitts', 'butter knife', 'serving plate']],
#  [['9”x13” baking dish'],
#   ['skillet', 'stove', 'spatula'],
#   ['toothpick', 'oven mitts'],
#   ['knife', 'spatula', 'large spoon']],
#  [['kitchen towel', 'plates'],
#   ['non stick skillet', 'tongs', 'plate', 'measuring cups'],
#   ['cutting board',
#    'chef’s knife',
#    'serving bowls',
#    'wooden spoon',
#    'serving spoon',
#    'measuring cups']],
#  [['pie plate', 'parchment paper', 'pie weights'],
#   ['oven mitts'],
#   ['dish towels', 'spoon', 'can opener '],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['knife', 'pie server', 'refrigerator']],
#  [['square baking dish'], ['fork', 'oven mitts'], ['oven mitts']],
#  [['baking sheets', 'parchment paper', 'silicone baking mat'],
#   ['spoon',
#    'baking sheets',
#    'parchment paper',
#    'silicone baking mat',
#    'plate'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['oven mitts', 'cooling rack', 'spatula']],
#  [['baking sheets', 'parchment paper', 'silicone baking mat'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['oven mitts', 'cooling rack', 'spatula']],
#  [['sheet pan', 'aluminum foil'],
#   ['oven mitts'],
#   ['oven mitts', 'meat thermometer'],
#   ['tongs', 'serving plate', 'platter']],
#  [['baking sheet', 'parchment paper'],
#   ['oven mitts'],
#   ['meat thermometer', 'oven mitts'],
#   ['fork', 'knife', 'cutting board']],
#  [['plate', 'fork', 'oven mitts'],
#   ['9x13-inch baking dish'],
#   ['oven mitts'],
#   ['oven mitts']],
#  [['baking sheets', 'parchment paper', 'silicone baking mat'],
#   ['baking sheets', 'parchment paper', 'silicone baking mat'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['oven mitts', 'cooling rack', 'spatula']],
#  [['baking sheet', 'parchment paper'],
#   ['measuring cups', 'measuring spoons', 'mixing bowl', 'rubber spatula'],
#   ['oven mitts'],
#   ['oven mitts']],
#  [['9”x13” baking dish'],
#   ['large pot'],
#   ['sieve', 'colander', 'large spoon', 'large pot'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['serving spoon', '9”x13” baking dish']],
#  [['oven'],
#   ['loaf pan'],
#   ['oven', 'oven mitts', 'toothpick'],
#   ['oven', 'oven mitts', 'toothpick'],
#   ['oven mitts', 'cooling rack', 'knife']],
#  [['frying pan', 'measuring spoons', 'oven mitts', 'plate'],
#   ['spoon',
#    'cutting board',
#    'chef’s knife',
#    'coffee grinder',
#    'spice grinder',
#    'blender',
#    'food processor',
#    'rubber spatula',
#    'measuring cups',
#    'measuring spoons'],
#   ['cutting board',
#    'chef’s knife',
#    'measuring spoons',
#    'Dutch oven',
#    'medium pot',
#    'wooden spoon'],
#   ['serving spoon', 'serving bowls']],
#  [['chef’s knife', 'cutting board', 'peeler'],
#   ['Dutch oven', 'large pot', 'lid', 'wooden spoon', 'measuring spoons'],
#   ['chef’s knife', 'cutting board'],
#   ['Dutch oven', 'large pot', 'lid', 'wooden spoon'],
#   ['ladle', 'serving bowls', 'measuring cups', 'measuring spoons']],
#  [['measuring spoons', 'whisk', 'rubber spatula', 'gallon-sized zip-top bags'],
#   ['oven'],
#   ['parchment paper', 'baking sheet'],
#   ['oven', 'oven mitts'],
#   ['oven', 'oven mitts'],
#   ['sauce pan', 'stove', 'whisk'],
#   ['spoon']],
#  [['oven'],
#   ['roasting pan', 'roasting rack', 'aluminum foil'],
#   ['oven', 'oven mitts', 'meat thermometer'],
#   ['oven', 'oven mitts', 'meat thermometer'],
#   ['roasting pan',
#    'roasting rack',
#    'meat thermometer',
#    'cutting board',
#    'knife']],
#  [['wooden spoon', 'measuring cups', 'measuring spoons', 'large mixing bowl'],
#   ['baking stone', 'baking sheets'],
#   ['knife', 'bench scraper', 'rolling pin', 'kitchen towel', 'baking sheet'],
#   ['oven mitts'],
#   ['oven mitts']],
#  [['baking sheet', 'parchment paper'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['knife']],
#  [['aluminum foil', 'baking sheet'],
#   ['oven mitts'],
#   ['oven mitts', 'fork'],
#   ['spatula']],
#  [['oven'],
#   ['baking sheet', 'parchment paper'],
#   ['oven', 'oven mitts'],
#   ['oven'],
#   ['skillet', 'stove', 'spatula', 'large plate', 'paper towels'],
#   ['knife', 'cutting board'],
#   ['large pot', 'stove', 'measuring spoons', 'whisk'],
#   ['rubber spatula', '9-inch square pan', 'large pot'],
#   ['oven', 'oven mitts'],
#   ['oven', 'oven mitts'],
#   ['oven mitts', 'serving spoon']],
#  [['baking sheet', 'parchment paper'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['serving bowl', 'rubber spatula']],
#  [['measuring cups', 'measuring spoons', 'gallon-sized zip-top bags'],
#   ['oven'],
#   ['baking sheet', 'parchment paper'],
#   ['skillet',
#    'stove',
#    'measuring spoons',
#    'tongs',
#    'baking sheet',
#    'parchment paper'],
#   ['oven', 'oven mitts', 'meat thermometer'],
#   ['oven', 'oven mitts', 'meat thermometer'],
#   ['oven mitts', 'tongs']],
#  [['oven'],
#   ['roasting pan', 'roasting rack', 'measuring cups'],
#   ['oven', 'oven mitts', 'meat thermometer'],
#   ['oven', 'oven mitts', 'roasting pan', 'roasting rack', 'aluminum foil'],
#   ['oven', 'oven mitts'],
#   ['oven', 'oven mitts'],
#   ['oven mitts', 'knife', 'cutting board', 'roasting pan', 'roasting rack']],
#  [['oven'],
#   ['9”x13” baking dish'],
#   ['skillet', 'stove', 'rubber spatula'],
#   ['large mixing bowl',
#    'whisk',
#    'measuring cups',
#    'measuring spoons',
#    'kitchen scale',
#    'rubber spatula'],
#   ['toothpick', 'oven', 'oven mitts'],
#   ['oven', 'oven mitts', 'toothpick'],
#   ['oven mitts', 'knife', 'spatula', 'serving spoon']],
#  [['9-inch square pan'],
#   ['oven mitts'],
#   ['oven mitts', 'toothpick'],
#   ['sifter']],
#  [['glass baking dish', 'knife', 'cutting board'],
#   ['measuring spoons', 'skillet', 'rubber spatula'],
#   ['spoon', 'measuring cups', 'measuring spoons', 'glass baking dish'],
#   ['oven mitts', 'fork'],
#   ['oven mitts'],
#   ['oven mitts']],
#  [['9x13-inch baking dish'],
#   ['measuring cups',
#    'measuring spoons',
#    'large mixing bowl',
#    'rubber spatula'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['serving spoon', 'spoon']],
#  [['baking sheet', 'parchment paper'],
#   ['measuring spoons', 'knife', 'cutting board', 'baking sheet'],
#   ['oven mitts', 'fork'],
#   ['bowl', 'measuring cups', 'measuring spoons', 'spoon'],
#   ['oven mitts', 'fork'],
#   ['platter', 'measuring cups', 'measuring spoons', 'spoon']],
#  [['oven'],
#   ['baking sheet', 'parchment paper'],
#   ['oven', 'oven mitts', 'meat thermometer'],
#   ['oven', 'oven mitts', 'meat thermometer'],
#   ['oven mitts', 'plate']],
#  [['oven'],
#   ['baking sheet', 'wire rack', 'aluminum foil'],
#   ['oven', 'oven mitts', 'meat thermometer'],
#   ['oven', 'oven mitts', 'meat thermometer'],
#   ['knife', 'cutting board']],
#  [['baking sheet', 'parchment paper'],
#   ['baking sheet', 'oven mitts'],
#   ['oven mitts'],
#   ['rubber spatula', 'serving bowl']],
#  [['measuring spoons', '9x13-inch baking dish', 'tongs'],
#   ['oven mitts'],
#   ['oven mitts', 'meat thermometer'],
#   ['spoon']],
#  [['paper towels', 'large plate'],
#   ['oven', 'refrigerator'],
#   ['baking sheet', 'aluminum foil', 'wire rack', 'knife'],
#   ['oven', 'oven mitts'],
#   ['skillet', 'stove', 'whisk', 'large mixing bowl'],
#   ['oven', 'oven mitts'],
#   ['pastry brush', 'large plate', 'tongs']],
#  [['baking sheet', 'parchment paper'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['plate', 'spatula']],
#  [['baking sheet', 'parchment paper'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['serving bowl']],
#  [['mixing bowl', 'sheet pan', 'parchment', 'tongs'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['cutting board', 'fork'],
#   ['measuring cups', 'spoon']],
#  [['oven'],
#   ['sheet pan', 'parchment paper'],
#   ['oven mitts'],
#   ['oven mitts', 'fork'],
#   ['serving spoon']],
#  [['9”x13” baking dish'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['oven mitts', 'serving spoon']],
#  [['oven'],
#   ['roasting pan', 'roasting rack', 'aluminum foil', 'paper towels'],
#   ['oven',
#    'oven mitts',
#    'spoon',
#    'pastry brush',
#    'meat thermometer',
#    'aluminum foil'],
#   ['oven', 'oven mitts', 'meat thermometer'],
#   ['cutting board', 'knife']],
#  [['oven'],
#   ['9”x13” baking dish'],
#   ['oven', 'oven mitts', 'toothpick'],
#   ['oven', 'oven mitts', 'toothpick'],
#   ['knife', 'serving spoon', 'sifter']],
#  [['9x13-inch baking dish'],
#   ['large pot', 'rubber spatula', 'measuring spoons'],
#   ['9x13-inch baking dish', 'rubber spatula', 'large pot'],
#   ['oven mitts'],
#   ['oven mitts']],
#  [['oven'],
#   ['baking sheet', 'parchment paper'],
#   ['oven', 'oven mitts'],
#   ['measuring spoons', 'plate'],
#   ['skillet', 'stove', 'measuring spoons', 'tongs', 'plate'],
#   ['oven', 'oven mitts', 'rubber spatula', 'tongs', 'meat thermometer'],
#   ['oven', 'oven mitts', 'meat thermometer'],
#   ['tongs']],
#  [['baking sheets', 'parchment paper', 'silicone baking mat'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['oven mitts', 'spatula', 'cooling rack']],
#  [['frying pan', 'wooden spoon', 'strainer', 'slotted spoon'],
#   ['pie pan', '9-inch pie pan'],
#   ['oven mitts'],
#   ['oven mitts']],
#  [['square baking dish', 'parchment paper'],
#   ['measuring spoons',
#    'large mixing bowl',
#    'whisk',
#    'pastry brush',
#    'square baking dish'],
#   ['oven mitts'],
#   ['oven mitts']],
#  [['parchment paper', 'baking sheet'],
#   ['oven mitts'],
#   ['knife', 'cutting board'],
#   ['rubber spatula', 'oven mitts'],
#   ['rubber spatula', 'oven mitts']],
#  [['baking sheet', 'parchment paper'],
#   ['fork', 'oven mitts'],
#   ['oven mitts', 'meat thermometer'],
#   ['baking sheet', 'parchment paper', 'spatula']],
#  [['roasting pan', 'roasting rack', 'aluminum foil'],
#   ['oven mitts'],
#   ['oven mitts', 'meat thermometer'],
#   ['oven mitts', 'meat thermometer'],
#   ['platter', 'knife']],
#  [['9x13-inch baking dish', 'heavy duty aluminum foil'],
#   ['oven mitts'],
#   ['zip-top bags', 'tongs'],
#   ['oven mitts'],
#   ['oven mitts', 'meat thermometer'],
#   ['tongs']],
#  [['loaf pan'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'cooling rack', 'knife']],
#  [['chef’s knife',
#    'cutting board',
#    'spoon',
#    'food processor',
#    'rubber spatula'],
#   ['Dutch oven', 'pot', 'measuring spoons', 'wooden spoon'],
#   ['chef’s knife', 'cutting board', 'measuring cups']],
#  [['baking sheet', 'parchment paper'],
#   ['oven mitts', 'fork'],
#   ['oven mitts', 'fork'],
#   ['spatula', 'plates', 'platter']],
#  [['oven'],
#   ['roasting pan', 'roasting rack', 'aluminum foil'],
#   ['oven', 'oven mitts', 'meat thermometer'],
#   ['oven', 'oven mitts', 'meat thermometer'],
#   ['knife', 'cutting board']],
#  [['oven'],
#   ['parchment paper'],
#   ['oven', 'oven mitts'],
#   ['oven mitts', 'measuring cups', 'kitchen scale', 'oven'],
#   ['oven', 'oven mitts', 'toothpick'],
#   ['oven', 'oven mitts', 'toothpick'],
#   ['oven mitts', 'refrigerator', 'cooling rack'],
#   ['knife', 'cutting board', '9”x13” baking dish', 'parchment paper']],
#  [['9”x13” baking dish'],
#   ['9”x13” baking dish', 'rubber spatula'],
#   ['oven mitts'],
#   ['serving spoon']],
#  [['cutting board', 'chef’s knife', 'measuring cups', 'mixing bowl'],
#   ['sheet pans', 'parchment paper'],
#   ['knife', 'cutting board', 'sheet pans'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['sheet pans', 'cooling rack', 'spatula']],
#  [['baking sheet', 'parchment paper'],
#   ['oven mitts', 'fork', 'spatula'],
#   ['oven mitts', 'fork'],
#   ['oven mitts', 'serving spoon']],
#  [['oven'],
#   ['knife', 'cutting board'],
#   ['Dutch oven', 'measuring spoons', 'stove'],
#   ['paper towels', 'large plate', 'measuring spoons'],
#   ['stove', 'Dutch oven', 'tongs'],
#   ['Dutch oven', 'oven mitts'],
#   ['oven', 'oven mitts', 'fork'],
#   ['oven', 'oven mitts', 'fork'],
#   ['serving plate', 'slotted spoon', 'fork']],
#  [['chef’s knife',
#    'cutting board',
#    'measuring spoons',
#    'medium mixing bowl',
#    'wooden spoon',
#    'rubber spatula',
#    'whisk'],
#   ['wok',
#    'large skillet',
#    'saute pan',
#    'tongs',
#    'medium mixing bowl',
#    'measuring spoons'],
#   ['wok',
#    'large skillet',
#    'saute pan',
#    'measuring spoons',
#    'tongs',
#    'wooden spoon']],
#  [['square baking dish'],
#   ['large pot'],
#   ['large pot', 'colander'],
#   ['cutting board', 'chef’s knife'],
#   ['large pot', 'measuring spoons', 'rubber spatula'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['oven mitts', 'serving spoon']],
#  [['oven'],
#   ['roasting pan', 'roasting rack', 'aluminum foil'],
#   ['measuring spoons', 'microwave', 'microwave-safe bowls'],
#   ['knife', 'cutting board'],
#   ['oven', 'oven mitts', 'meat thermometer'],
#   ['oven', 'oven mitts', 'meat thermometer'],
#   ['knife', 'cutting board']],
#  [['knife',
#    'cutting board',
#    'measuring cups',
#    'measuring spoons',
#    'stand mixer',
#    'paddle attachment',
#    'hand mixer',
#    'large mixing bowl',
#    'rubber spatula'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['measuring cups', 'medium mixing bowl', 'cooling rack', 'sheet pans']],
#  [['oven'],
#   ['sheet pan', 'parchment paper'],
#   ['oven mitts'],
#   ['oven mitts', 'meat thermometer'],
#   ['spatula']],
#  [['cake pan'],
#   ['toothpick', 'oven mitts'],
#   ['toothpick', 'oven mitts'],
#   ['cooling rack'],
#   ['cake stand', 'offset spatula', 'parchment paper']],
#  [['peeler', 'paring knife', 'pie plate'],
#   ['fork', 'oven mitts'],
#   ['oven mitts']],
#  [['chef’s knife', 'measuring spoons', 'aluminum foil'],
#   ['oven mitts', 'aluminum foil'],
#   ['oven mitts', 'aluminum foil'],
#   ['peeler', 'chef’s knife', 'cutting board', 'large mixing bowl'],
#   ['large saucepan', 'Dutch oven', 'colander'],
#   ['large saucepan', 'wooden spoon', 'serving bowl', 'serving spoon']],
#  [['muffin liners', 'muffin pan'],
#   ['toothpick', 'oven mitts'],
#   ['toothpick', 'oven mitts'],
#   ['cooling rack'],
#   ['decorating bags', 'decorating tips', 'offset spatula']],
#  [['oven'],
#   ['sheet pan', 'aluminum foil'],
#   ['tongs'],
#   ['oven mitts', 'meat thermometer'],
#   ['tongs']],
#  [['9x13-inch baking dish'],
#   ['oven mitts'],
#   ['oven mitts', 'toothpick'],
#   ['cooling rack'],
#   ['serrated knife', 'cake server']],
#  [['oven'],
#   ['spring form pan'],
#   ['measuring cups', 'kitchen scale', 'microwave', 'microwave-safe bowls'],
#   ['mixing bowl', 'fork'],
#   ['oven', 'oven mitts'],
#   ['oven', 'oven mitts'],
#   ['stand mixer',
#    'measuring cups',
#    'kitchen scale',
#    'rubber spatula',
#    'whisk attachment'],
#   ['oven', 'oven mitts'],
#   ['oven', 'oven mitts'],
#   ['refrigerator', 'oven', 'oven mitts'],
#   ['knife']],
#  [['oven'],
#   ['9”x13” baking dish', 'measuring cups', 'spoon'],
#   ['skillet', 'stove', 'measuring spoons', 'rubber spatula'],
#   ['medium mixing bowl', 'whisk'],
#   ['skillet', 'stove', 'measuring spoons', 'rubber spatula'],
#   ['large mixing bowl', 'measuring cups', 'rubber spatula'],
#   ['oven', 'oven mitts'],
#   ['oven', 'oven mitts', 'spatula'],
#   ['serving spoon', 'spatula']],
#  [['sheet pan'], ['oven mitts', 'fork'], ['oven mitts', 'fork']],
#  [['oven'],
#   ['bundt pan'],
#   ['oven', 'oven mitts', 'toothpick'],
#   ['oven', 'oven mitts', 'toothpick'],
#   ['oven mitts', 'butter knife', 'serving plate', 'sifter']],
#  [['9”x13” baking dish'],
#   ['wooden spoon', 'stove', 'large pot'],
#   ['oven mitts'],
#   ['serving spoon']],
#  [['peeler', 'chef’s knife', 'cutting board'],
#   ['Dutch oven', 'colander'],
#   ['stand mixer', 'paddle attachment'],
#   ['rubber spatula', 'serving bowl', 'serving spoon']],
#  [['plate', 'fork'],
#   ['9x13-inch baking dish'],
#   ['oven mitts'],
#   ['oven mitts']],
#  [['9x5-inch loaf pan'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'butter knife', 'plate'],
#   ['knife', 'plate']],
#  [['colander', 'tea towel', 'chef’s knife', 'cutting board'],
#   ['medium saucepan', 'measuring spoons', 'rubber spatula'],
#   ['chef’s knife', 'cutting board'],
#   ['frying pan', 'measuring spoons', 'rubber spatula'],
#   ['chef’s knife', 'cutting board', 'pairing knife'],
#   ['oven mitts', 'sheet pan', 'meat thermometer'],
#   ['oven mitts', 'sheet pan', 'meat thermometer'],
#   ['sheet pan',
#    'medium saucepan',
#    'scissors',
#    'knife',
#    'cutting board',
#    'platter']],
#  [['roasting pan', 'roasting rack', 'aluminum foil'],
#   ['oven', 'oven mitts', 'meat thermometer'],
#   ['oven', 'oven mitts', 'meat thermometer'],
#   ['knife', 'cutting board']],
#  [['9”x13” baking dish'],
#   ['large pot', 'colander'],
#   ['rubber spatula', 'large pot', 'sauce pan'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['oven mitts']],
#  [['cast-iron skillet'],
#   ['microwave-safe bowls', 'measuring spoons', 'kitchen scale', 'spoon'],
#   ['large mixing bowl',
#    'measuring cups',
#    'measuring spoons',
#    'kitchen scale',
#    'rubber spatula',
#    'whisk'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'toothpick'],
#   ['knife']],
#  [['pairing knife', 'peeler', 'melon baller'],
#   ['ovenproof skillet', 'wooden spoon'],
#   ['ovenproof skillet', 'wooden spoon', 'oven mitts', 'tongs'],
#   ['oven mitts', 'turkey baster', 'spoon', 'pairing knife'],
#   ['oven mitts', 'pairing knife'],
#   ['turkey baster', 'spoon', 'wooden spoon', 'oven mitts', 'serving spoon']],
#  [['pie pan', 'cake pan'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['small mixing bowl', 'whisk', 'spoon'],
#   ['serving bowl', 'tongs']],
#  [['loaf pan'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'cooling rack', 'knife']],
#  [['cutting board',
#    'chef’s knife',
#    'large mixing bowl',
#    'wooden spoon',
#    'measuring cups',
#    'measuring spoons'],
#   ['large saucepan', 'rice cooker', 'measuring cups'],
#   ['peeler', 'chef’s knife', 'cutting board'],
#   ['cast-iron skillet',
#    'heavy bottomed skillet',
#    'measuring spoons',
#    'wooden spoon',
#    'medium mixing bowls',
#    'aluminum foil',
#    'plates',
#    'tongs'],
#   ['serving bowls', 'serving spoon', 'aluminum foil'],
#   ['cast-iron skillet',
#    'heavy bottomed skillet',
#    'wooden spoon',
#    'tongs',
#    'plate'],
#   ['serving bowls', 'serving spoon', 'tongs', 'spatula', 'spoon']],
#  [['baking sheet', 'parchment paper'],
#   ['oven mitts', 'fork'],
#   ['oven mitts', 'fork']],
#  [['Dutch oven', 'measuring spoons', 'rubber spatula'],
#   ['oven mitts', 'Dutch oven'],
#   ['oven mitts', 'Dutch oven', 'baking sheet', 'aluminum foil'],
#   ['oven mitts'],
#   ['oven mitts']],
#  [['oven'],
#   ['roasting pan', 'roasting rack', 'aluminum foil'],
#   ['oven', 'oven mitts', 'meat thermometer'],
#   ['oven', 'oven mitts', 'meat thermometer'],
#   ['knife', 'cutting board']],
#  [['paper towels', 'heavy-bottomed skillet'],
#   ['large nonstick skillet', 'measuring spoons', 'tongs'],
#   ['plate'],
#   ['large nonstick skillet', 'wooden spoon'],
#   ['serving spoon', 'measuring spoons']],
#  [['sheet pan', 'parchment paper'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['measuring cups']],
#  [['oven'],
#   ['baking sheet', 'aluminum foil'],
#   ['oven', 'oven mitts'],
#   ['oven', 'oven mitts']],
#  [['baking sheet', 'parchment paper'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['serving bowl', 'spatula']],
#  [['baking sheet', 'parchment paper'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['measuring cups', 'plate']],
#  [['baking sheet', 'parchment paper'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['plate']],
#  [['oven'],
#   ['baking sheet', 'parchment paper'],
#   ['oven', 'oven mitts'],
#   ['oven', 'oven mitts'],
#   ['tongs']],
#  [['sheet pan', 'parchment paper'], ['oven mitts'], ['oven mitts', 'fork']],
#  [['roasting pan', 'roasting rack', 'aluminum foil'],
#   ['oven mitts'],
#   ['oven mitts', 'meat thermometer'],
#   ['oven mitts', 'meat thermometer'],
#   ['platter', 'knife', 'fork']],
#  [['food processor', 'measuring spoons', 'measuring cups'],
#   ['sheet pans', 'parchment paper'],
#   ['oven mitts'],
#   ['oven mitts', 'spatula'],
#   ['oven mitts', 'spatula', 'cooling racks'],
#   ['sifter']],
#  [['oven'],
#   ['baking sheet', 'aluminum foil'],
#   ['oven', 'oven mitts', 'fork'],
#   ['knife', 'cutting board', 'large mixing bowl', 'spoon'],
#   ['oven', 'oven mitts'],
#   ['oven', 'oven mitts'],
#   ['plate']],
#  [['cutting board', 'measuring spoons', 'aluminum foil'],
#   ['oven'],
#   ['roasting pan', 'roasting rack', 'aluminum foil'],
#   ['stove', 'measuring spoons', 'tongs', 'extra-large skillet'],
#   ['roasting pan', 'roasting rack', 'aluminum foil', 'tongs'],
#   ['oven', 'oven mitts', 'meat thermometer'],
#   ['knife', 'cutting board', 'large mixing bowl'],
#   ['oven', 'oven mitts', 'meat thermometer'],
#   ['roasting pan', 'roasting rack', 'cutting board', 'knife', 'oven mitts']],
#  [['9”x13” baking dish'],
#   ['oven mitts'],
#   ['toothpick', 'oven mitts'],
#   ['knife', 'spatula', 'large spoon']],
#  [['baking sheet', 'fork'],
#   ['oven mitts'],
#   ['skillet', 'rubber spatula', 'measuring spoons'],
#   ['large mixing bowl', 'whisk', 'measuring cups', 'measuring spoons'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['oven mitts', 'knife']],
#  [['baking sheets', 'parchment paper', 'silicone baking mat'],
#   ['spoon',
#    'baking sheets',
#    'parchment paper',
#    'silicone baking mat',
#    'plate'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['oven mitts', 'cooling rack', 'spatula']],
#  [['9”x13” baking dish'],
#   ['microwave-safe bowls', 'plastic wrap'],
#   ['knife', 'cutting board'],
#   ['measuring spoons', 'wooden spoon', 'large pot'],
#   ['rubber spatula', '9”x13” baking dish'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['oven mitts', 'serving spoon']],
#  [['oven'],
#   ['muffin liners', 'muffin pan'],
#   ['oven', 'oven mitts'],
#   ['oven', 'oven mitts', 'toothpick'],
#   ['oven mitts']],
#  [['baking sheet', 'parchment paper'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['mixing bowl', 'measuring cups', 'rubber spatula', 'tongs', 'plate']],
#  [['baking sheet', 'aluminum foil'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['serrated knife']],
#  [['oven'],
#   ['9”x13” baking dish'],
#   ['oven', 'oven mitts', 'toothpick'],
#   ['oven', 'oven mitts', 'toothpick'],
#   ['knife', 'serving spoon', 'sifter']],
#  [['square pan'],
#   ['square pan', 'oven mitts'],
#   ['toothpick', 'oven mitts'],
#   ['sharp knife', 'refrigerator']],
#  [['oven'],
#   ['baking sheet', 'aluminum foil', 'roasting rack', 'knife'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['plate']],
#  [['oven'],
#   ['springform pan'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['refrigerator']],
#  [['baking sheet', 'parchment paper'],
#   ['skillet', 'measuring spoons', 'rubber spatula'],
#   ['knife', 'cutting board'],
#   ['oven mitts'],
#   ['measuring cups', 'spoon']],
#  [['oven'],
#   ['knife', 'cutting board'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['serving spoon']],
#  [['baking sheet', 'aluminum foil', 'knife'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['knife']],
#  [['9”x13” baking dish', 'spoon', 'measuring cups'],
#   ['plate'],
#   ['spoon', 'measuring cups', '9”x13” baking dish'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['serving spoon']],
#  [['bundt pan', 'measuring spoons'],
#   ['oven mitts', 'toothpick'],
#   ['small saucepan',
#    'measuring spoons',
#    'zester grater',
#    'knife',
#    'small bowl',
#    'whisk'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'butter knife', 'platter']],
#  [['knife', 'cutting board'],
#   ['Dutch oven', 'large pot', 'wooden spoon', 'measuring spoons'],
#   ['chef’s knife', 'cutting board', 'ladle', 'serving bowls']],
#  [['silicone baking mat', 'parchment paper', 'baking sheet'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['kitchen scale',
#    'mixing bowl',
#    'measuring cups',
#    'measuring spoons',
#    'mixer',
#    'rubber spatula']],
#  [['oven'],
#   ['baking sheet', 'parchment paper'],
#   ['knife', 'cutting board', 'oven', 'oven mitts'],
#   ['oven', 'oven mitts'],
#   ['spatula']],
#  [['9”x13” baking dish'],
#   ['large pot', 'colander'],
#   ['measuring cups',
#    'measuring spoons',
#    'large mixing bowl',
#    'rubber spatula'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['oven mitts']],
#  [['measuring spoons', '9-inch square pan'],
# ...
#  [['sheet pan', 'parchment paper'],
#   ['oven mitts'],
#   ['oven mitts', 'meat thermometer'],
#   ['spatula']],
#  [['sheet pans'],
#   ['sheet pans', 'oven mitts'],
#   ['chef’s knife', 'cutting board'],
#   ['oven mitts', 'sheet pans', 'tongs', 'fork'],
#   ['medium mixing bowl', 'spatula', 'aluminum foil'],
#   ['oven mitts', 'sheet pans'],
#   ['chef’s knife',
#    'cutting board',
#    'can opener ',
#    'colander',
#    'zester grater'],
#   ['measuring cups', 'sheet pans', 'oven mitts', 'tongs'],
#   ['non stick frying pan',
#    'measuring cups',
#    'measuring spoons',
#    'wooden spoon'],
#   ['oven mitts', 'sheet pans'],
#   ['aluminum foil', 'sheet pans'],
#   ['platter', 'large plates', 'spatula', 'spoon', 'tongs']],
#  [['baking sheet', 'parchment paper'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['plate']],
#  [['baking sheet', 'parchment paper'],
#   ['oven mitts', 'fork', 'spatula'],
#   ['oven mitts', 'fork']],
#  [['baking sheet', 'aluminum foil'], ['oven mitts'], ['oven mitts']],
#  [['oven'],
#   ['baking sheet', 'parchment paper'],
#   ['knife', 'cutting board', 'oven', 'oven mitts'],
#   ['oven', 'oven mitts'],
#   ['serving spoon']],
#  [['muffin liners', 'muffin pan'],
#   ['oven mitts'],
#   ['toothpick', 'oven mitts']],
#  [['loaf pan'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'cooling rack', 'knife']],
#  [['baking sheet', 'parchment paper'],
#   ['oven mitts'],
#   ['oven mitts', 'fork'],
#   ['spatula']],
#  [['spoon',
#    'zester grater',
#    'grater',
#    'cutting board',
#    'chef’s knife',
#    'reamer'],
#   ['Dutch oven', 'large pot', 'wooden spoon', 'measuring cups'],
#   ['rubber spatula',
#    'food processor',
#    'measuring cups',
#    'Dutch oven',
#    'large pot'],
#   ['metal skewers',
#    'grill pan',
#    'cast-iron skillet',
#    'tongs',
#    'oven mitts',
#    'medium mixing bowl',
#    'plate'],
#   ['Dutch oven', 'large pot', 'measuring spoons', 'lid'],
#   ['ladle', 'serving bowls', 'measuring spoons']],
#  [['spring form pan'],
#   ['microwave-safe bowls',
#    'measuring cups',
#    'spoon',
#    'glass measuring cup',
#    'measuring spoons',
#    'stand mixer',
#    'paddle attachment',
#    'rubber spatula'],
#   ['measuring cups',
#    'stand mixer',
#    'paddle attachment',
#    'rubber spatula',
#    'measuring spoons',
#    'spring form pan'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'toothpick'],
#   ['freezer', 'spring form pan'],
#   ['small saucepan',
#    'measuring cups',
#    'rubber spatula',
#    'small bowl',
#    'large bowl'],
#   ['whisk', 'small saucepan', 'small bowl', 'large bowl'],
#   ['stand mixer', 'whisk attachment', 'rubber spatula', 'measuring cups'],
#   ['small saucepan',
#    'measuring cups',
#    'measuring spoons',
#    'rubber spatula',
#    'small bowl',
#    'large bowl',
#    'spoons'],
#   ['large bowl', 'rubber spatula', 'small saucepan', 'small bowl'],
#   ['serving plate']],
#  [['baking sheet', 'parchment paper'],
#   ['oven mitts', 'rubber spatula'],
#   ['oven mitts'],
#   ['serving spoon']],
#  [['small bowl', 'measuring cups', 'measuring spoons'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['cooling rack', 'fork', 'butter knife', 'muffin pan'],
#   ['plastic container']],
#  [['baking sheet', 'aluminum foil'],
#   ['saute pan', 'stove', 'measuring spoons', 'spatula'],
#   ['oven mitts']],
#  [['square baking dish'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'toothpick']],
#  [['oven'],
#   ['roasting pan', 'roasting rack', 'aluminum foil'],
#   ['oven', 'oven mitts', 'meat thermometer'],
#   ['oven', 'oven mitts', 'meat thermometer'],
#   ['meat thermometer',
#    'oven mitts',
#    'roasting pan',
#    'roasting rack',
#    'aluminum foil',
#    'cutting board',
#    'knife']],
#  [['oven'],
#   ['muffin liners', 'muffin pan'],
#   ['oven', 'oven mitts'],
#   ['oven', 'oven mitts', 'toothpick'],
#   ['oven mitts']],
#  [['baking sheet', 'parchment paper'], ['oven mitts'], ['fork', 'oven mitts']],
#  [['shallow baking dish', 'chef’s knife', 'cutting board'],
#   ['sheet pan', 'oven mitts', 'large mixing bowl'],
#   ['non stick frying pan',
#    'measuring cups',
#    'measuring spoons',
#    'wooden spoon'],
#   ['measuring cups',
#    'measuring spoons',
#    'medium mixing bowl',
#    'whisk',
#    'wooden spoon',
#    'shallow baking dish',
#    'aluminum foil'],
#   ['oven mitts', 'kitchen thermometer'],
#   ['oven mitts', 'kitchen thermometer'],
#   ['serving spoon']],
#  [['baking sheet', 'parchment paper'],
#   ['measuring cups', 'microwave-safe bowls', 'paper towels', 'oven mitts'],
#   ['cheesecloth'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['skillet', 'spatula']],
#  [['baking sheets', 'parchment paper', 'silicone baking mat'],
#   ['spoon',
#    'baking sheets',
#    'parchment paper',
#    'silicone baking mat',
#    'plate'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['oven mitts', 'cooling rack', 'spatula']],
#  [['chef’s knife', 'medium mixing bowls', 'measuring spoons'],
#   ['Dutch oven', 'large pot', 'tongs', 'cutting board', 'measuring spoons'],
#   ['Dutch oven',
#    'large pot',
#    'wooden spoon',
#    'ladle',
#    'bowls',
#    'measuring spoons']],
#  [['sheet pan', 'aluminum foil'],
#   ['rubber spatula', 'wooden spoon'],
#   ['oven mitts', 'fork'],
#   ['small mixing bowl', 'whisk', 'pepper mill'],
#   ['spatula', 'serving plate']],
#  [['9x13-inch baking dish'],
#   ['saucepan', 'rubber spatula', 'measuring spoons'],
#   ['spoons', 'saucepan', '9x13-inch baking dish'],
#   ['saucepan', 'measuring spoons', 'measuring cups', 'whisk'],
#   ['rubber spatula', 'measuring cups', '9x13-inch baking dish'],
#   ['oven mitts'],
#   ['oven mitts']],
#  [['plate', 'fork'],
#   ['9x13-inch baking dish'],
#   ['oven mitts'],
#   ['oven mitts']],
#  [['cake pan'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'toothpick'],
#   ['large mixing bowl',
#    'measuring cups',
#    'measuring spoons',
#    'hand mixer',
#    'rubber spatula',
#    'kitchen scale'],
#   ['offset spatula', 'parchment paper', 'cake stand', 'serving plate']],
#  [['sheet pan', 'aluminum foil'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['serrated knife']],
#  [['9”x13” baking dish'],
#   ['oven mitts'],
#   ['oven mitts', 'toothpick'],
#   ['knife', 'spatula', 'large spoon']],
#  [['baking sheets', 'parchment paper', 'silicone baking mat'],
#   ['spoon',
#    'baking sheets',
#    'parchment paper',
#    'silicone baking mat',
#    'plate'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['oven mitts', 'cooling rack', 'spatula']],
#  [['9x13-inch baking dish'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'toothpick'],
#   ['baking sheet', 'parchment paper'],
#   ['measuring cups', 'microwave-safe bowls', 'spoon'],
#   ['cake pop sticks', 'baking sheet', 'parchment paper'],
#   ['double boiler', 'microwave-safe bowls', 'measuring spoons', 'spoon'],
#   ['cake pop sticks', 'baking sheet', 'parchment paper'],
#   ['cake pop stand']],
#  [['oven'],
#   ['roasting pan', 'roasting rack', 'aluminum foil'],
#   ['oven', 'oven mitts', 'meat thermometer'],
#   ['oven', 'oven mitts', 'meat thermometer'],
#   ['cutting board', 'knife']],
#  [['oven'],
#   ['muffin liners', 'muffin pan'],
#   ['oven', 'oven mitts'],
#   ['oven', 'oven mitts', 'toothpick'],
#   ['oven mitts', 'cooling rack']],
#  [['glass baking dish', 'knife', 'cutting board'],
#   ['measuring spoons', 'skillet', 'rubber spatula'],
#   ['oven mitts', 'fork'],
#   ['oven mitts'],
#   ['oven mitts']],
#  [['baking sheets', 'silicone baking mat', 'parchment paper'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['oven mitts', 'wooden spoon'],
#   ['measuring cups', 'measuring spoons', 'cooling rack']],
#  [['baking sheet', 'parchment paper'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['knife', 'cutting board']],
#  [['baking sheet', 'parchment paper'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['knife']],
#  [['chef’s knife',
#    'cutting board',
#    'spoon',
#    'zester grater',
#    'measuring spoons'],
#   ['cast-iron skillet', 'frying pan', 'measuring spoons', 'wooden spoon'],
#   ['reamer', 'measuring spoons', 'ladle', 'serving bowls']],
#  [['cake pan'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'toothpick'],
#   ['knife', 'cooling rack', 'oven mitts'],
#   ['offset spatula', 'parchment paper', 'cake stand', 'serving plate']],
#  [['baking sheet', 'fork'],
#   ['oven mitts'],
#   ['large mixing bowl', 'whisk', 'measuring cups', 'measuring spoons'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['oven mitts', 'knife']],
#  [['sheet pan', 'wire baking rack', 'paper towel', 'measuring spoons'],
#   ['oven mitts'],
#   ['zester grater',
#    'grater',
#    'measuring cups',
#    'measuring spoons',
#    'small mixing bowl',
#    'fork',
#    'chef’s knife',
#    'cutting board'],
#   ['oven mitts'],
#   ['pastry brush', 'platter', 'tongs', 'small bowl']],
#  [['sheet pan'],
#   ['can opener ',
#    'colander',
#    'chef’s knife',
#    'cutting board',
#    'measuring cups',
#    'reamer'],
#   ['non stick frying pan', 'measuring spoons', 'spatula'],
#   ['oven mitts', 'spatula', 'sheet pan'],
#   ['non stick frying pan', 'spatula', 'oven mitts', 'sheet pan'],
#   ['platter', 'spatula', 'tongs', 'spoons', 'measuring cups']],
#  [['microwave-safe bowls', 'measuring cups'],
#   ['stand mixer', 'paddle attachment', 'measuring spoons'],
#   ['oven mitts', 'toothpick'],
#   ['small saucepan', 'measuring cups', 'measuring spoons', 'spoon'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'cooling rack', 'toothpick', 'knife'],
#   ['microwave-safe bowls', 'measuring cups', 'whisk'],
#   ['serving plate']],
#  [['muffin pan', 'cupcake liners'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'toothpick'],
#   ['offset spatula', 'piping bag', 'decorating tips']],
#  [['food processor',
#    'medium mixing bowl',
#    'wooden spoon',
#    'plastic container'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['cooling rack', 'oven mitts'],
#   ['knife', 'pie server', 'butter knife']],
#  [['baking sheets', 'parchment paper'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['large pot', 'tongs', 'spoon'],
#   ['serving spoon']],
#  [['sheet pan', 'parchment paper'],
#   ['paper towels', 'measuring spoons', 'plate'],
#   ['oven mitts', 'tongs', 'meat thermometer'],
#   ['oven mitts', 'meat thermometer'],
#   ['spatula']],
#  [['baking sheet', 'parchment paper', 'rubber spatula', 'measuring spoons'],
#   ['oven mitts'],
#   ['saucepan', 'measuring cups', 'measuring spoons', 'whisk'],
#   ['oven mitts', 'fork', 'rubber spatula'],
#   ['oven mitts', 'fork'],
#   ['serving bowls']],
#  [['loaf pan'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'cooling rack', 'knife']],
#  [['9x13-inch baking dish'],
#   ['large skillet', 'tongs', 'measuring spoons'],
#   ['plate', 'tongs'],
#   ['cutting board',
#    'knife',
#    'measuring spoons',
#    'large skillet',
#    'rubber spatula'],
#   ['cutting board', 'knife', 'mandoline'],
#   ['spoon', 'large skillet', 'rubber spatula'],
#   ['9x13-inch baking dish', 'aluminum foil', 'rubber spatula'],
#   ['oven mitts'],
#   ['oven mitts', 'meat thermometer']],
#  [['9”x13” baking dish'],
#   ['oven mitts'],
#   ['oven mitts', 'toothpick'],
#   ['knife', 'spatula', 'large spoon']],
#  [['9”x13” baking dish'],
#   ['large pot', 'colander'],
#   ['measuring cups',
#    'measuring spoons',
#    'rubber spatula',
#    'food processor',
#    'blender'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['oven mitts']],
#  [['baking sheet', 'parchment paper'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['spatula']],
#  [['9”x13” baking dish'],
#   ['stove',
#    'measuring spoons',
#    'large pot',
#    'kitchen scale',
#    'rubber spatula'],
#   ['oven mitts'],
#   ['serving spoon']],
#  [['baking sheet', 'aluminum foil', 'knife', 'cutting board'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['serrated knife', 'oven mitts']],
#  [['oven mitts', 'toothpick'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'bowl']],
#  [['roasting pan', 'roasting rack', 'aluminum foil', 'knife'],
#   ['large skillet', 'rubber spatula', 'measuring spoons'],
#   ['mixing bowl', 'measuring cups', 'rubber spatula'],
#   ['oven mitts', 'meat thermometer'],
#   ['oven mitts', 'meat thermometer'],
#   ['meat thermometer', 'oven mitts', 'roasting pan', 'roasting rack'],
#   ['cutting board', 'knife']],
#  [['baking sheet', 'parchment paper'],
#   ['oven mitts'],
#   ['oven mitts', 'fork'],
#   ['spatula']],
#  [['baking sheet', 'parchment paper'],
#   ['oven', 'oven mitts'],
#   ['knife', 'cutting board'],
#   ['large pot', 'stove', 'measuring spoons', 'whisk'],
#   ['large pot', '9-inch square pan', 'rubber spatula'],
#   ['oven', 'oven mitts'],
#   ['oven', 'oven mitts'],
#   ['oven mitts', 'serving spoon']],
#  [['baking sheet', 'parchment paper'], ['oven mitts'], ['oven mitts']],
#  [['oven'],
#   ['sheet pan', 'aluminum foil'],
#   ['spatula'],
#   ['oven mitts', 'meat thermometer'],
#   ['tongs']],
#  [['9”x13” baking dish'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'toothpick'],
#   ['cooling rack'],
#   ['offset spatula', 'refrigerator']],
#  [['baking sheets', 'parchment paper'],
#   ['oven mitts'],
#   ['measuring cups', 'kitchen scale', 'measuring spoons'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['measuring spoons']],
#  [['roasting pan', 'roasting rack', 'aluminum foil'],
#   ['measuring spoons', 'skillet', 'stove', 'rubber spatula'],
#   ['measuring spoons', 'large mixing bowl', 'rubber spatula'],
#   ['oven', 'oven mitts', 'meat thermometer'],
#   ['oven', 'oven mitts', 'meat thermometer'],
#   ['knife', 'cutting board']],
#  [['sheet pan', 'parchment paper'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['pastry brush']],
#  [['baking sheet', 'parchment paper'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['serving bowl', 'rubber spatula']],
#  [['oven'],
#   ['baking sheet', 'aluminum foil'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['paper towels', 'flat plate', 'spatula']],
#  [['oven'],
#   ['baking sheet', 'parchment paper'],
#   ['oven', 'oven mitts', 'rubber spatula'],
#   ['oven', 'oven mitts', 'fork'],
#   ['serving spoon']],
#  [['silicone baking mat', 'parchment paper', 'baking sheets'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['cooling racks']],
#  [['oven'],
#   ['muffin pan'],
#   ['skillet', 'stove', 'rubber spatula'],
#   ['large plate', 'paper towels', 'skillet', 'rubber spatula'],
#   ['measuring spoons', 'skillet', 'stove', 'rubber spatula'],
#   ['large mixing bowl',
#    'measuring cups',
#    'measuring spoons',
#    'kitchen scale',
#    'whisk',
#    'rubber spatula'],
#   ['oven', 'oven mitts', 'toothpick'],
#   ['oven', 'oven mitts', 'toothpick'],
#   ['oven mitts', 'knife', 'plates']],
#  [['chef’s knife',
#    'cutting board',
#    'medium mixing bowl',
#    'measuring spoons',
#    'whisk'],
#   ['frying pan', 'wok', 'tongs', 'bowl'],
#   ['serving plate', 'serving spoon']],
#  [['oven'],
#   ['spring form pan'],
#   ['measuring cups', 'kitchen scale', 'microwave', 'microwave-safe bowls'],
#   ['mixing bowl', 'fork'],
#   ['oven', 'oven mitts'],
#   ['oven', 'oven mitts'],
#   ['stand mixer',
#    'measuring cups',
#    'kitchen scale',
#    'rubber spatula',
#    'whisk attachment'],
#   ['oven', 'oven mitts'],
#   ['oven', 'oven mitts'],
#   ['refrigerator'],
#   ['butter knife', 'spring form pan'],
#   ['knife']],
#  [['9-inch square pan'],
#   ['measuring spoons', 'wooden spoon', 'large pot'],
#   ['9-inch square pan', 'rubber spatula'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['serving spoon']],
#  [['baking sheet', 'parchment paper'],
#   ['measuring spoons', 'baking sheet', 'parchment paper', 'rubber spatula'],
#   ['oven mitts'],
#   ['oven mitts', 'fork'],
#   ['small mixing bowl', 'measuring spoons', 'whisk'],
#   ['platter', 'measuring cups', 'measuring spoons']],
#  [['oven'],
#   ['sheet pan', 'aluminum foil'],
#   ['oven mitts', 'meat thermometer'],
#   ['tongs']],
#  [['baking sheet', 'parchment paper'],
#   ['oven mitts', 'spatula', 'fork'],
#   ['oven mitts', 'fork']],
#  [['oven'],
#   ['roasting pan', 'roasting rack', 'aluminum foil'],
#   ['oven', 'oven mitts', 'aluminum foil', 'meat thermometer'],
#   ['oven', 'oven mitts', 'meat thermometer'],
#   ['cutting board', 'knife']],
#  [['silicone baking mat', 'parchment paper', 'baking sheets'],
#   ['mixing bowl',
#    'measuring cups',
#    'measuring spoons',
#    'mixer',
#    'kitchen scale'],
#   ['oven mitts'],
#   ['oven mitts'],
#   ['cooling racks']],
#  [['cake pan'],
#   ['oven mitts', 'toothpick'],
#   ['oven mitts', 'toothpick'],
#   ['wire rack', 'oven mitts'],
#   ['medium saucepan', 'measuring cups', 'whisk', 'spoons'],
#   ['measuring cups', 'measuring spoons', 'rubber spatula', 'medium saucepan'],
#   ['offset spatula', 'large plate']]]

# %%
txt ='9”x13” baking dish'
x
